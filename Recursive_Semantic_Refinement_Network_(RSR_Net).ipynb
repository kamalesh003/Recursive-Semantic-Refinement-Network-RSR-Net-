# %% [markdown]
# ---
#
# #  Recursive Semantic Refinement Network (RSR-Net)
#
# ## Project Goal
# The **Recursive Semantic Refinement Network (RSR-Net)** is an innovative approach to abstractive summarization. Instead of generating text word-by-word, RSR-Net is designed to iteratively refine a fixed-size semantic embedding of a summary until it converges to the desired output state, which is semantically close to the ground-truth summary. This technique leverages principles from Deep Equilibrium Models (DEQ) and Recurrent Neural Networks (RNNs).
#
# The project uses the standard **CNN/DailyMail** dataset and **BART-base embeddings** for all inputs and targets.
#
# ---
#
# ## 💡 Core Methodology: Iterative Embedding Correction
#
# RSR-Net treats the summarization task as a **regression problem in a high-dimensional semantic space**.
#
# 1.  **Input Preparation:** The source article ($\mathbf{x}$) and the target summary ($\mathbf{y}_{\text{true}}$) are converted into fixed-size **BART-base encoder embeddings** (768 dimensions).
# 2.  **Recursion:** The core model iteratively consumes the document context ($\mathbf{x}$) and refines the current summary state ($\mathbf{y}$) and an internal latent state ($\mathbf{z}$).
# 3.  **Refinement:** After multiple recursive steps, the final state ($\mathbf{y}_{\text{hat}}$) represents the network's best prediction of the target summary embedding.
# 4.  **Loss:** Training minimizes the distance (using **Mean Squared Error**) between the predicted summary embedding ($\mathbf{y}_{\text{hat}}$) and the ground-truth summary embedding ($\mathbf{y}_{\text{true_emb}}$).
#
# ---
#
# ## 🧠 Model Architecture: `RecursionModel`
#
# The `RecursionModel` is a simple feed-forward network at its core, designed for recurrent application:
#
# | State | Role | Dimension (Adjusted) |
# | :--- | :--- | :--- |
# | **Input ($\mathbf{x}$)** | **Document Context** (Fixed for all steps) | 768 (BART $\text{d_model}$) |
# | **State ($\mathbf{y}$)** | **Current Summary Embedding** (Refined output) | 768 (BART $\text{d_model}$) |
# | **Latent ($\mathbf{z}$)** | **Internal Memory** (Accumulates context) | 64 ($\text{latent_dim}$) |
# | **Combined Input** | $\text{torch.cat}([\mathbf{x}, \mathbf{y}, \mathbf{z}])$ | $768 + 768 + 64$ |
#
# The network's output consists of a refined summary state ($\mathbf{y}_{\text{out}}$), an auxiliary output ($\mathbf{y}_{\text{aux}}$), and a new latent state ($\mathbf{z}_{\text{new}}$).
#
# ## 🔄 Recursive Training Mechanism
#
# The training process uses two nested recursive functions that implement a form of **Deep Supervision** to stabilize training and ensure convergence.
#
# ### 1. `latent_recursion(x, y, z, net, n=4)`
#
# This is the **inner loop** that runs the core network $n$ times. It quickly pushes the state towards a stable point for the current input:
# $$\mathbf{y}_{t+1}, \mathbf{z}_{t+1} = \text{net}(\mathbf{x}, \mathbf{y}_t, \mathbf{z}_t)$$
# The output $\mathbf{y}$ and $\mathbf{z}$ from the final step are then passed to the outer loop.
#
# ### 2. `deep_recursion(x, y, z, net, n=4, T=3)`
#
# This is the **outer loop** that enables stable gradient propagation:
# * **Preconditioning ($\text{T}-1$ steps):** The states $\mathbf{y}$ and $\mathbf{z}$ are updated repeatedly using `latent_recursion` while detaching the gradient ($\text{with torch.no_grad}()$). This stabilizes the initial state for the final, critical step.
# * **Final Step (1 step):** The network runs `latent_recursion` one last time **with the gradient enabled**, producing the final predicted embedding $\mathbf{y}_{\text{hat}}$ and a confidence score $\mathbf{q}_{\text{hat}}$.
# * **State Update:** The resulting $\mathbf{y}$ and $\mathbf{z}$ are **detached** before being passed back to the main training loop, ensuring the model trains on sequential segments of the refinement process.
#
# ### Loss Function
#
# The combined loss function for semantic refinement is:
# $$
# \text{Loss} = \text{MSE}(\mathbf{y}_{\text{hat}}, \mathbf{y}_{\text{true_emb}}) + 0.1 \times \text{BCE}(\mathbf{q}_{\text{hat}}, \mathbf{1})
# $$
#
# * **$\text{MSE Loss}$:** Measures the distance between the predicted summary embedding ($\mathbf{y}_{\text{hat}}$) and the target summary embedding ($\mathbf{y}_{\text{true_emb}}$).
# * **$\text{Auxiliary Loss}$:** A **Binary Cross-Entropy (BCE)** loss applied to the sigmoid confidence $\mathbf{q}_{\text{hat}}$, which encourages the network to be highly confident (score $\to 1$) in its final prediction.
#
# ---

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class RecursionModel(nn.Module):
    def __init__(self, input_dim, hidden_dim=64, latent_dim=32, num_classes=3):
        super().__init__()
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.latent_dim = latent_dim
        self.num_classes = num_classes

        # Core network
        self.fc1 = nn.Linear(input_dim + num_classes + latent_dim, hidden_dim)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.bn2 = nn.BatchNorm1d(hidden_dim)
        self.fc_latent = nn.Linear(hidden_dim, latent_dim)
        self.fc_out = nn.Linear(hidden_dim, num_classes)
        self.fc_aux = nn.Linear(hidden_dim, num_classes)

    def forward(self, x, y=None, z=None):
        batch_size = x.size(0)
        device = x.device
        if y is None:
            y = torch.zeros(batch_size, self.num_classes, device=device)
        if z is None:
            z = torch.zeros(batch_size, self.latent_dim, device=device)

        concat_input = torch.cat([x, y, z], dim=-1)
        h = F.relu(self.bn1(self.fc1(concat_input)))
        h = F.relu(self.bn2(self.fc2(h)))

        z_new = F.relu(self.fc_latent(h))
        y_out = self.fc_out(h)
        y_aux = self.fc_aux(h)
        return y_out, y_aux, z_new

def latent_recursion(x, y, z, net, n=4):
    for _ in range(n):
        y, _, z = net(x, y, z)
    return y, z

def deep_recursion(x, y, z, net, n=4, T=3):
    # Preconditioning steps (no gradient)
    for _ in range(T-1):
        with torch.no_grad():
            y, z = latent_recursion(x, y, z, net, n)
    # Final step with gradient
    y, z = latent_recursion(x, y, z, net, n)
    y_hat = y
    q_hat = torch.sigmoid(y_hat.max(dim=-1).values)  # confidence
    return (y.detach(), z.detach()), y_hat, q_hat

# Example training loop with deep supervision
def train_model(train_dataloader, net, optimizer, device, N_supervision=3):
    net.train()
    for x_input, y_true in train_dataloader:
        x_input, y_true = x_input.to(device), y_true.to(device)
        batch_size = x_input.size(0)

        y = torch.zeros(batch_size, net.num_classes, device=device)
        z = torch.zeros(batch_size, net.latent_dim, device=device)

        for _ in range(N_supervision):
            x_emb = x_input  # optional embedding here
            (y_detach, z_detach), y_hat, q_hat = deep_recursion(x_emb, y, z, net)

            # Losses
            ce_loss = F.cross_entropy(y_hat, y_true)
            aux_loss = F.binary_cross_entropy(q_hat, torch.ones_like(q_hat))
            loss = ce_loss + 0.1 * aux_loss

            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(net.parameters(), 1.0)
            optimizer.step()

            # Optional dynamic early stopping
            if q_hat.mean() > 0.95:
                break

# %%
# In Colab terminal / code cell
# !wget -c https://huggingface.co/datasets/ccdv/cnn_dailymail/resolve/main/cnn_stories.tgz
# !wget -c https://huggingface.co/datasets/ccdv/cnn_dailymail/resolve/main/dailymail_stories.tgz

# Extract
# !mkdir -p ./cnn_dailymail
# !tar -xvzf cnn_stories.tgz -C ./cnn_dailymail
# !tar -xvzf dailymail_stories.tgz -C ./cnn_dailymail
# Out:
# Streaming output truncated to the last 5000 lines.
# ./dailymail/stories/ed8674cc15b29a87d8df8de1efee353d71122272.story
# ./dailymail/stories/6d7bc2f757e1975510b5009a0605b781226e57f8.story
# ./dailymail/stories/d77c038b6366e852ff157ff23b9db80c02e67e32.story
# ./dailymail/stories/40c2ac49da0284e75cc0aebaaa8c6e29ed7d7cc9.story
# ./dailymail/stories/b95a8098e6594b92c5c3aac80d55f884ee13a60e.story
# ./dailymail/stories/9ef8de0159d987fba67911dc6595dbcf667b76e2.story
# ./dailymail/stories/87edb976f8c49008f2bd83f9e567784616319e5b.story
# ./dailymail/stories/80c4b62473f179325602d5de85463991f0287167.story
# ./dailymail/stories/b06808437cf8b6f41b7888001ebecdcfe7de6d34.story
# ./dailymail/stories/95a942ed60852ec257f145d8bafd0206295dab7b.story
# ./dailymail/stories/c148c5858d263cd70d8d1d1de925ed8cd7615733.story
# ./dailymail/stories/7829822e79cb17ed920bb14d896f114961da3972.story
# ./dailymail/stories/e90f1740b53be02fe5174185a61a25c5106596ea.story
# ./dailymail/stories/eae3803b67ea2eded61ba78592c0e6577f28cdf6.story
# ./dailymail/stories/4d3b6c6b0d3cde2c2bf615e027c47997493b8ceb.story
# ./dailymail/stories/be88290f614fe4faf9431ceec6efc0d9c3cef851.story
# ./dailymail/stories/31b802fc9797fba5f23cd7b67f832837d935cf96.story
# ./dailymail/stories/f2c5101a0773cf124e56fae02a7cd2f9e12c1323.story
# ./dailymail/stories/0a467ac090a8128ae5bcb7afda582b6e6be529aa.story
# ./dailymail/stories/6eeabdecf5dac571f9d230ad8f753baaede5578f.story
# ./dailymail/stories/24be2b68feb5297daddea3fe39149c41e6347114.story
# ./dailymail/stories/a3778e3bc9f16cde26c2735f89b816cbf2a3975f.story
# ./dailymail/stories/d8c8afd278aa23f0d8ac7e0c215422a02bae2f0c.story
# ./dailymail/stories/5f4fcacd7e634fc9d49d96e1012ece864a18bfe7.story
# ./dailymail/stories/2c07caf8011d121b691f0519f4b9d68147efd4e0.story
# ./dailymail/stories/64d847a2f06d277f895e41e5f751c6a8fb76f136.story
# ./dailymail/stories/91086fc7b571b86d7254c77bb66fa7fe8945b9ae.story
# ./dailymail/stories/3f54c155837c177d84e53252dcc8fc58bf539618.story
# ./dailymail/stories/9426b3bbf644379a90d7c87875cf8446c9eac064.story
# ./dailymail/stories/35f55fa2a95a88bf20f2502dbec87de6cbc74b19.story
# ./dailymail/stories/c93c8ea6afde4325698e60a5766b4e214b6e76bd.story
# ./dailymail/stories/8a710e7466f8ec6f94fc015f0a9acf51f270253a.story
# ./dailymail/stories/2d89a81ba902ea598a2d3206b2b03fb75d5132fa.story
# ./dailymail/stories/8a9aa876b2c52e2c6763984784840f8262c8a9da.story
# ./dailymail/stories/a4ba204692edde9fcf23d1748b6e0fdd926e42a1.story
# ./dailymail/stories/676e233fb4f7fa26c7f84cedc07a861217774d5c.story
# ./dailymail/stories/3de81bfba6c9c3a85ba7b2f589b092fcae0f1ac6.story
# ./dailymail/stories/dcdfea09663ff0b93b5d928592b1cf7c3895890e.story
# ./dailymail/stories/2a0df244c19767cb7ea83394418849679e4a3bfa.story
# ./dailymail/stories/f125cb2296b75abddb09435c5f3ef89f9df44714.story
# ./dailymail/stories/cee1c2efe137471fee7a744597fdc425f2d067f8.story
# ./dailymail/stories/20691ea516fe73a0e8e3d3fe1d5f4940208169a1.story
# ./dailymail/stories/d75e0b880a13c761f60263972269b26e4c8cbae0.story
# ./dailymail/stories/1f9a04e9efb8cea5069224e6ce385cb1d340b32e.story
# ./dailymail/stories/7a5079c3c3872bfe9a5ec1b4badf25d8ea0908e6.story
# ./dailymail/stories/f95244de22a1d11955f5f0cfebc721d5f318b8ae.story
# ./dailymail/stories/ba2cc7036dbb26f386586a1758d42b59d4bbd384.story
# ./dailymail/stories/f8549c0447002563334f6055725818f8ffef1c8a.story
# ./dailymail/stories/e77c0c57c88e87eed3a63eb2a1b559b02f069861.story
# ./dailymail/stories/7440fb68dd5b62090a3bfe0725e8df089b6833bd.story
# ./dailymail/stories/a944e8f85f943e02db2d059e0bf672bacd9f40d9.story
# ./dailymail/stories/e14698bd5377e41dd118cb1bfda81e6a56c8eb93.story
# ./dailymail/stories/f939eeae282ebee55526b159e900c067d660ea61.story
# ./dailymail/stories/4e57567cf250b139c72c7927a76b4133b79aefd5.story
# ./dailymail/stories/972528f7fb6cd1850db0a19af1365a2c78e976c3.story
# ./dailymail/stories/496791f3112cdbeb63c48743dfc60e9a72699da6.story
# ./dailymail/stories/2ff01ac080fabb637aa780c216a94c5123b40b08.story
# ./dailymail/stories/522d1e95ef7321628c8c312060395021f250f0d2.story
# ./dailymail/stories/d71f7ce85e58f186270db5cb1af0a14492d9139b.story
# ./dailymail/stories/bf1a286b9decf062e52109be61a0b6ffcc6dbe56.story
# ./dailymail/stories/5b206e792b751b2d859adb68ef13ad7270dc87da.story
# ./dailymail/stories/6e89b1d9d449a23d4a2ad23935426855992a6df4.story
# ./dailymail/stories/1c887d925dca646f96341545f11456a6010fa4ad.story
# ./dailymail/stories/9b58be88ffba01a33bcefa5f6792f681d13488c5.story
# ./dailymail/stories/533f09cbe1df3a0e531c91e7e78040aad8e243a1.story
# ./dailymail/stories/c3f9da7257a4cc56bc995abcde1f5aef9a4c2d1b.story
# ./dailymail/stories/ec6cbef91316c0089aff4e8601a5890a50010de3.story
# ./dailymail/stories/d405c84b015c6b183073f5d40a380237a2a7b7d4.story
# ./dailymail/stories/28a812eb24d6eaa8db7411f8dcc8cf6ff29dc2a4.story
# ./dailymail/stories/e5d8b62e39c3109ff1b5e7a022f6a5371e572ab7.story
# ./dailymail/stories/e5a842249bacc6c9d3f432d4e651e6989dd0dd33.story
# ./dailymail/stories/1bb9e794eb2ee37abf78807a2d92e0e95f1d2362.story
# ./dailymail/stories/8355b68d226f7d3e5ea9725e9ca50381e4f2885b.story
# ./dailymail/stories/37f4e3243f3e31206b860bc6308d6b607d815357.story
# ./dailymail/stories/876b7a15e927d6bc24ecfca56698624a64ed7fed.story
# ./dailymail/stories/26bd79ebc869d449eaa214d1233384e8dfae1f3f.story
# ./dailymail/stories/ccb70f69b1f331660e82e9a4239fc895bef48e94.story
# ./dailymail/stories/a8187ec10ba8578b7e3960bab17cff39a143d42c.story
# ./dailymail/stories/2dfa0295b48249b24c373af7319a1b3ec027a549.story
# ./dailymail/stories/d11b1ca8c6f508b68b1832bd6e4404b95692d3fb.story
# ./dailymail/stories/e2f2bb91d9712eb194086410e8c3765e30e0a16c.story
# ./dailymail/stories/3bd0212c2468fba5bfd9428ac25339a3a50e4bcc.story
# ./dailymail/stories/8fd4e592fac2954d526ae74801791ab48cb6ec50.story
# ./dailymail/stories/fc5b438a9e81b4a2e2ef057b844e38b08f2997fe.story
# ./dailymail/stories/bd47660646956a2257203d201077b7a300f87f04.story
# ./dailymail/stories/ef891b77b1a415e0f30a548e4bf9125c743f4458.story
# ./dailymail/stories/1be447f7820e9f4d276781f5ce1a89d79ded6d4c.story
# ./dailymail/stories/ce1e37648e7083a7e4934a8c9697449b46af37bc.story
# ./dailymail/stories/e2d4a8c8e5b3ba50108d66b3e726da22bedb470b.story
# ./dailymail/stories/726c1b40aa0e71a65e09fd93bbf9c1d3723d54ae.story
# ./dailymail/stories/4776b2e669e75793a4ac2a5c5a9b718070d39007.story
# ./dailymail/stories/ad23070413ef243484af4dd0c4656a387992ffc7.story
# ./dailymail/stories/f6692420d8718f0bd56bb0f4ecdbabfa3418d01a.story
# ./dailymail/stories/7638ccd8fff2a7a5c0541faf3b52dbb443845e49.story
# ./dailymail/stories/8fd0a345b959044cbda6a58480fdbebae93c5931.story
# ./dailymail/stories/e48958ec11d31e4b266cdff63bdc40f8e8c429fd.story
# ./dailymail/stories/e53e402a10143a4f7e665b4d010e318cf07d6a8f.story
# ./dailymail/stories/f056dc691ab03ccc7b1f7a1a15ec69e238453dd5.story
# ./dailymail/stories/685573e9aaed8da47e163a983034505f7e3f90c6.story
# ./dailymail/stories/f495aa17ed0a9ff57e8686947c396fb525b8fda3.story
# ./dailymail/stories/5c09b29c6b6b147188a03c9d41cdae712898034c.story
# ./dailymail/stories/57c28e2bef33d1bb2b37048ebfb7b7977916ca07.story
# ./dailymail/stories/2a62c6747c871e3419e0c2d2c616e5302d6ff71f.story
# ./dailymail/stories/46d0d741c56facd28698cdfb62f594dd03f8f123.story
# ./dailymail/stories/c5e799bbca47602c6cf99a6c0714dc807888b041.story
# ./dailymail/stories/f78250ca155b9d3c374ede947a0f0d255aa205e9.story
# ./dailymail/stories/22f0851cde0393be08fea8f2e1a7b52a1ca14dfc.story
# ./dailymail/stories/95c9accc2a1856e7979ebc5366008ca4f89e0720.story
# ./dailymail/stories/ea65fecbe36355c4d2b354190078c63c048c5837.story
# ./dailymail/stories/fee25d231aadb74370cfc694c25122c4dde731fc.story
# ./dailymail/stories/ca072ac2181bbfae3e12cee0554847872772e2fa.story
# ./dailymail/stories/81e53e5049586cf9cb9c160041798165a95b78c4.story
# ./dailymail/stories/3d3f07fcfff8b8e82d50149a6be8a9f62475d451.story
# ./dailymail/stories/9a1e2b03bb3a09fb3049cd2aaba09f8c665369b0.story
# ./dailymail/stories/1ce2607594bd24aaddd8e915039c879f5dfc7576.story
# ./dailymail/stories/4ea872899b3bcc80e1b35b6bc0018eb116dc3671.story
# ./dailymail/stories/1ae7d8c3af1fa0b0a0a7d9fcb61b21336188ee8c.story
# ./dailymail/stories/dffb812ad66b9cc284fb8f3a8e50f34fc065ec0c.story
# ./dailymail/stories/ffb7ee9b3ecdf550b97218276dd7f066624cc9a0.story
# ./dailymail/stories/ccab00149a54850ce9cfd427727b77dce05c6821.story
# ./dailymail/stories/82823d3ad50d6b4df9ac80168d9dfd18205b2be9.story
# ./dailymail/stories/27d8a5c29118cc2dda27fba7ee9d8da8f55d2f48.story
# ./dailymail/stories/20014281583945a7218cde2387fc369e725a2f95.story
# ./dailymail/stories/aab238ffef9ea27adcdc25882ba9e261aaf93995.story
# ./dailymail/stories/50153026567a2f0dcdd4f27a588345ce925100ea.story
# ./dailymail/stories/30278707947e07d030751635ac82da5d32b02dc8.story
# ./dailymail/stories/833dfb87fab3d018ba2a10d04f1faef4be357fa3.story
# ./dailymail/stories/26c30be5fb9d4a97f4b0c96d1eee263e6542874e.story
# ./dailymail/stories/6ef7858821b6a120694c695e32b8c7f779db68cc.story
# ./dailymail/stories/16c3fea26b874fd94cfbb9730733b030fa2326b4.story
# ./dailymail/stories/d175d30ba48888476aa346b6128ab54a495397e5.story
# ./dailymail/stories/d8c6a41a3d11d0cfde012556755e7501dab61be4.story
# ./dailymail/stories/ccbcb0b13f9b54c20af61071635e420be85ec185.story
# ./dailymail/stories/018a3a3294375748b23855150924a1ea614dc989.story
# ./dailymail/stories/5cc9f4737d6745f6cf2c2755ea461f33ef68cda5.story
# ./dailymail/stories/ff0e4d00d60b722f3b4a737f47e45c6d2482da39.story
# ./dailymail/stories/3c839aad78d74d7e579e8e74bd01423cf5038387.story
# ./dailymail/stories/00d7e25ca69634e8319fe815d095c07ad2595436.story
# ./dailymail/stories/eed8e74c596c44d4ec2d0c35f9094ba55b2d6c0e.story
# ./dailymail/stories/a31f204d0593cd396da31e2a94ce7a0880981b61.story
# ./dailymail/stories/fa2ba5ddb671a58fbb631bac963cb5bd159f2189.story
# ./dailymail/stories/3a33a9492d3965c2befe681cb9a01a503d0e993f.story
# ./dailymail/stories/0d4c41fb418b4b1e684c64fc8f1af48addda919c.story
# ./dailymail/stories/a8ded81e4b4128cfd8feb5c9a20b0701a612683d.story
# ./dailymail/stories/34a9e05ccf31044a0b3bf39f5ff1a7367de6c609.story
# ./dailymail/stories/a80cb0d3e4c15e04415938cac7cce8999ae2713c.story
# ./dailymail/stories/c0e7fa000674cc4d3fddcac9ead1e92619b3d92e.story
# ./dailymail/stories/e269d56d6fb15738b179cb40eedc24c38b82ea51.story
# ./dailymail/stories/87b05e3bcd4bd9e0d8dfe0dd3a996ea13c557e26.story
# ./dailymail/stories/207923621d28e67c9c5eb210a40c5d3848863ced.story
# ./dailymail/stories/6e9a31180f995a23b8e0006e6007173b2b5f691d.story
# ./dailymail/stories/340b450dbc69645ad9fdebfb012aa083805e4bc1.story
# ./dailymail/stories/6303f297cc5d7ad1293a00a63cc31116a6f755e3.story
# ./dailymail/stories/59318a64f323d8a62005bcd65b92faf250a559c2.story
# ./dailymail/stories/7a7cbe439d4d7d1d5476c5217a78f26452b7702e.story
# ./dailymail/stories/8c768d54b0c3a098cec7683f0b2dec6b05db1f2a.story
# ./dailymail/stories/3dd0d9dd4ad02930414a8a5980fa247b45f479d5.story
# ./dailymail/stories/7bc35053ecd2c804480500bb0ba4e72744e77ff0.story
# ./dailymail/stories/7d939aabc17e7ead656de73f5519471700c75bd3.story
# ./dailymail/stories/e87984842cccc73e1fcb5da99f27c0a0d6355796.story
# ./dailymail/stories/46996e1f8c215bc3831b88b342135ad70b57a4b2.story
# ./dailymail/stories/cdfed29602a38426efe5e757a141802543d8b94b.story
# ./dailymail/stories/4069e2b43c873e43ea2ae1774399118f3e59f78d.story
# ./dailymail/stories/ef2ec424af2389c8b3b30128d8c35e356d3ac1ab.story
# ./dailymail/stories/fd474cc5b186d2ea43c9052a82bcb7ff2ed0eea7.story
# ./dailymail/stories/ff13de54d72b20246a8f6989e4fff15c3409b164.story
# ./dailymail/stories/593147e04721ca2bba0eafa26be3eddb52ba0f38.story
# ./dailymail/stories/6686b083834c00ca978a4cfe478d97f7ebd2d880.story
# ./dailymail/stories/9bb3da478a771eb848e49a20a26cf464f45e7d11.story
# ./dailymail/stories/60de51f49e8be589d67659101fb8054431791a1f.story
# ./dailymail/stories/44656dd9ae04f90248e8a8f2e280840850d65e3d.story
# ./dailymail/stories/d550bddacd94aa6de794d4abb6f3c2ee15edfa12.story
# ./dailymail/stories/c5e7f88f9235246a60a95464c0fdb85f4ca04ac1.story
# ./dailymail/stories/f1cc8599d68e0bae8dd6f87366445a77d482e238.story
# ./dailymail/stories/2f0a1343fa98bd20ace9e5c104cd1e65a9534add.story
# ./dailymail/stories/cf6136e01a46d3d41159a8648814bbdb6644053e.story
# ./dailymail/stories/dbfc736fbe192c6cfde044b4067be802afab7f53.story
# ./dailymail/stories/bfe753294d8252348c2509f45a305bae4224a9db.story
# ./dailymail/stories/3e8170f0e3a16f48bc52648ceeab79104df96987.story
# ./dailymail/stories/39041cc9d9379d3bad1a6ea90926150344913818.story
# ./dailymail/stories/10d6bb32d2d70228970fcf1d9bbd28a59e9099e0.story
# ./dailymail/stories/cc9c4d4e8458cdbc7d29325674e5371fd810549f.story
# ./dailymail/stories/b67ef7855dae05dfd1f21dab53ecc01b8bebb7cc.story
# ./dailymail/stories/77cbebc15ddd116cdefdab8edf997069cd74bfce.story
# ./dailymail/stories/af96b867cfff0ed51d80fcc56397934dd435a14b.story
# ./dailymail/stories/9727b837320a563a9c7ce019244affcc9186d2cc.story
# ./dailymail/stories/237dd7327fac6d74e5c9979d1475558106e5d346.story
# ./dailymail/stories/48b70b1239bc5870c895afae82edc474e7dcff3a.story
# ./dailymail/stories/65369cdbe0cd1dcac00ee23d308c3f23a5a51427.story
# ./dailymail/stories/4d4263032d5e9bf0985494a2d7133c10bf62626b.story
# ./dailymail/stories/e0b603c2c3fd29c360d984879da495d7be744b02.story
# ./dailymail/stories/954cab56d8aeef2c86481ab745060fd28f1a516d.story
# ./dailymail/stories/00119229166ae09a6ef25c0e10b101ef9eb9cca3.story
# ./dailymail/stories/67527b729a0ef3052c64f68a7abfe4761c20171c.story
# ./dailymail/stories/dd7200d8975b2f30512d4b813b123b8d54330b47.story
# ./dailymail/stories/1468ee5137be00db3b811dc138d4fd7708e2bf8e.story
# ./dailymail/stories/838a7c3e94bb0e583761b1b49e3a4c692c9d1518.story
# ./dailymail/stories/87ede14d78de475446b5dfff4a7a4df2afacd2d1.story
# ./dailymail/stories/74fda2f87d6f4bcac184c248d3a4755c32e7af6e.story
# ./dailymail/stories/7f4890436db82e1e593cbde0b0c4444b400765b5.story
# ./dailymail/stories/7c6d51e3ed1e902fff6716aead093b8ffeb9521c.story
# ./dailymail/stories/d00aba8ccab9056f8e2df5cc98d686dcce8ed420.story
# ./dailymail/stories/a1fee9ea774980bfbbaaa8480447f9257aa11f27.story
# ./dailymail/stories/87e93812ef7c6c859049b0983d12cf24ca1e0492.story
# ./dailymail/stories/702320739b97904d829d50b4931526273a868c54.story
# ./dailymail/stories/278d2d883eaae5cc958b012f576e9585607636c6.story
# ./dailymail/stories/bca48ae4d9b3b2de64f47db59cd92233fc6d99b0.story
# ./dailymail/stories/b2a125c75ac11199e7f16f69461ca48b1223a116.story
# ./dailymail/stories/67a6d6114d4ba172f7cfb05dca1bad6d0219afcf.story
# ./dailymail/stories/286b3bfb32146f6476744ebfc2a1acb5a76d5195.story
# ./dailymail/stories/cf77272c6066263fe7b60cb06454f918a99deef3.story
# ./dailymail/stories/904e2d6edd61c1f353f0a81160aaf7cfa756f547.story
# ./dailymail/stories/dec8335fcfad23699750be2aabc694b34c2effe9.story
# ./dailymail/stories/ff97c416b511c2baeaa79f440e763ea224972e82.story
# ./dailymail/stories/7df9a0e24671f29a5db6d68195c768054d0dc20e.story
# ./dailymail/stories/d7231d1398268503f528ded067154b57f7f05bf5.story
# ./dailymail/stories/241493bccd82f6ae66a0c729c76aff2233250ebb.story
# ./dailymail/stories/dac1ca3741f100a5767a68d01a9198dd0611bcd9.story
# ./dailymail/stories/05f21f93f21bd93fbcb1af1e354bdb35540810ca.story
# ./dailymail/stories/c8ed59b31d28e5d55be977130928b7d81cd42f55.story
# ./dailymail/stories/762cad2cfd523a8e2eac9cd8bd9acd2b6a59c091.story
# ./dailymail/stories/038bff961f0d9f2b68796d691f703ceee0685b0c.story
# ./dailymail/stories/010848ae03bc64e5b1167ca85161bfbb3b84b341.story
# ./dailymail/stories/cd11cccb7d5eb4e3b77dbd5bf9df07f89c952c52.story
# ./dailymail/stories/b90c23305f19a38a13e879bb23ef1ea2fe665045.story
# ./dailymail/stories/50485070c53c89d40420bfea69c67ca7d7c9f96d.story
# ./dailymail/stories/1eb63b9c71456849c8960cef888fcccaf4672bbc.story
# ./dailymail/stories/08d311ba0556eee362377ae958509449c2094e86.story
# ./dailymail/stories/48ed302090205d8427c2c413b8fcbe0738ffa9a9.story
# ./dailymail/stories/67bec738ec3da9efb7edeb704f8e5536be9d57a9.story
# ./dailymail/stories/27af7517fdbf4f21a4c642c3e530f6de1ce05e30.story
# ./dailymail/stories/9a176cc351281d5446fbebbccaf7469df672c7f0.story
# ./dailymail/stories/6aaf7b50c64a6974ca82a54326922ce9242e91c2.story
# ./dailymail/stories/1b37dbe792ecd725848ddbb424a89069b8db63cc.story
# ./dailymail/stories/cf97519c18a8a3401993344439b144e475899334.story
# ./dailymail/stories/1b9e77eafe784bc146313ab992998a4b1b63e51e.story
# ./dailymail/stories/4523ba72ce198cb004dcca42c5c5af092e4fffcc.story
# ./dailymail/stories/cd5c1899474ad78bb3e935b5b9c08a859b58b6ae.story
# ./dailymail/stories/895b12bbb9419ad45d012ea89b8bf014e7bd975d.story
# ./dailymail/stories/81c6658dff79c94096f9f0defda8ccdf13815e48.story
# ./dailymail/stories/831ad546d0acb4b55de7a041424122b8dad328b4.story
# ./dailymail/stories/804654194f735d2c10002c2526d20cc44b3993e0.story
# ./dailymail/stories/cf44e8a1c324e7c901272c8fab2d26045bb546c0.story
# ./dailymail/stories/f74980312b1ca74238db2be17b8a429f69d95d64.story
# ./dailymail/stories/b1c4b2ebdbf6196ecc8bb89710c3c8dc93496b0e.story
# ./dailymail/stories/10c4e3a118d7fcb86bdad68501fe24d8684fe273.story
# ./dailymail/stories/94cfba77e1990f1f7fc3be2d006c867dcf175607.story
# ./dailymail/stories/6fcec5c5df13821cfb8d9aabdd9bacd6bdfd4b7d.story
# ./dailymail/stories/6d8fb1777aa7e62ec47beb0111c912ba45871e4b.story
# ./dailymail/stories/d3076ec90c3dcf0553ed28ed2809f64dc6969750.story
# ./dailymail/stories/e5ca03e8570c7c54c7a2e16b4bb153fd145548b4.story
# ./dailymail/stories/2d0337099e6c4439903062b3fcc6c2a06736a5b8.story
# ./dailymail/stories/fe36570537b13ccfd55861472d2360ec73bf1b8d.story
# ./dailymail/stories/cc4b8927a1ce9a998668c782a43b964c80aa8b78.story
# ./dailymail/stories/0b2bfde6328e003f4aa8fb24ea506f8adea8cfbe.story
# ./dailymail/stories/b52cb9c3722126ab377180dd84d582622d204d1b.story
# ./dailymail/stories/74eb30d2305b9f2cb3c0e6debdd06cb1b446723d.story
# ./dailymail/stories/c0991c37a1153c84488fff7303581bf856923903.story
# ./dailymail/stories/973d483d353f656c99cec320aaec65c9f86941d3.story
# ./dailymail/stories/35e8076e8aaef46bd7087bd63ac819f013622af5.story
# ./dailymail/stories/48cc25d1b938315a08c984829a2c8cc6757e563a.story
# ./dailymail/stories/8e5e02cf74c8beb89c5256ab29988d17891149a5.story
# ./dailymail/stories/6d4f71675acbb980f28bd570e46d12b2d204c441.story
# ./dailymail/stories/d39c020af27a17b073bd17a79e59738b3fbc9107.story
# ./dailymail/stories/1ab64d5f514d27961b06b6e05258efb7b95647d9.story
# ./dailymail/stories/4ace609aa39e20be38d58d263b8281277da18d5d.story
# ./dailymail/stories/95e782a2b0715ce652972b92546be1859f95b614.story
# ./dailymail/stories/20bed2bbae11450691d153a0f8070b669ee2e0fd.story
# ./dailymail/stories/d197f1f79dea5ae34b41ea9138623da7d3ab5ada.story
# ./dailymail/stories/7693fd2596d04cf7248a7ad78ccc682a3024c711.story
# ./dailymail/stories/a1ca9dacbb18d502d31045ab1671a270c80967b3.story
# ./dailymail/stories/00fcb8be0187eb7e65e60c0b135f728953eb52c0.story
# ./dailymail/stories/f46626a2e8f7dc58bdc1df2100e26faff6af40ed.story
# ./dailymail/stories/072f8ed7b853799ee527dcd2d289ebe245220bae.story
# ./dailymail/stories/de77007aec616f8350ff34380c08b22b79a41c56.story
# ./dailymail/stories/b47b8a5d0449a28cfaea85ca77de87fd977c49a9.story
# ./dailymail/stories/6b979fb1d45700b7a1a32ce3739ad602489062d2.story
# ./dailymail/stories/af350430dde26680632eed30218bb78dd7f128fc.story
# ./dailymail/stories/8656fb31c1bb23fa1c598e1e2dfdc6352d714260.story
# ./dailymail/stories/ccbb5f7f33eb72be3b84102f6452baf68f2b46e1.story
# ./dailymail/stories/3fdfee1af2e12ca0948c3f0b69c0a45a6811bf7b.story
# ./dailymail/stories/82e87698b2fcf661436dd1e12e7dacc806be3a19.story
# ./dailymail/stories/175bccba192d848c017c4327f8537f82c918b10f.story
# ./dailymail/stories/9c651aad3cf8232fa5c9c417a2cd56bf96cce2b8.story
# ./dailymail/stories/e944dba22ff1ad03fce3783cddb879fe67251b7b.story
# ./dailymail/stories/b8b1d2901f783880fa08438211d678e15d7a65c9.story
# ./dailymail/stories/b82c2a0839b28376976734615f8d6f476a4ceddb.story
# ./dailymail/stories/829a7c379095baa91b1a273298b1babb7a70bcb9.story
# ./dailymail/stories/7b68be37b256d43a8a5008c519506bdd7141f4e7.story
# ./dailymail/stories/619ea073e3c76143bb78aec53cc687e28755128b.story
# ./dailymail/stories/a81e236d739f993b2b8c43c7772d982f8fbed637.story
# ./dailymail/stories/f8d279e2c58bc9ab114c902522a12f4548f56d5a.story
# ./dailymail/stories/a6a7df3e25e13dccd5df2e4f3cd7524bff686aed.story
# ./dailymail/stories/cfc6c5ad5bfad9f5c15bc8c6a1d42773b86b3083.story
# ./dailymail/stories/54a2d1b0a4d9d938c9d6b1dc8ac21b53282a986e.story
# ./dailymail/stories/6d42da4a039eecec8520b8467f668561b4642f30.story
# ./dailymail/stories/79a733f7a0ea241738d3574df416be0c5deb3979.story
# ./dailymail/stories/49414fb8b1dc8cd81d99ca329d0c165a6bd5554a.story
# ./dailymail/stories/de1d0728cee04927e5664028781297c5c2b4830c.story
# ./dailymail/stories/87b6241c4336a005a2b3cf52e92c2415f174cc57.story
# ./dailymail/stories/4167bd6b8e14cf6daaca651c74d2e3422a687283.story
# ./dailymail/stories/5997e29e8032aa49b510365f49fff279b80692e4.story
# ./dailymail/stories/6e428f5bb2f05f5e66c69a3efe9dfad219c0da8a.story
# ./dailymail/stories/18f1cdb20b9074711119f7bd54d1f6459803f82c.story
# ./dailymail/stories/8c7851099c5fa244aea9a09a575db92dec55d354.story
# ./dailymail/stories/6bc8d202b4baba2802e73820728a7bfb6b626b07.story
# ./dailymail/stories/b6614f4c2e24643dfafa46ef37e6c8d84ffd7119.story
# ./dailymail/stories/00f72bffb3bc4d927cfff380e0ce2f94b6d3cb2b.story
# ./dailymail/stories/d4ae67cb89d437ae68092f3857f13412bc66468e.story
# ./dailymail/stories/276accccc393a99e52e7385b4c15502eb090ef8b.story
# ./dailymail/stories/c76095166076e9f0a8a77c0de31f3315c73f078d.story
# ./dailymail/stories/221173a61f76961f747309cd5e98844405b09fb6.story
# ./dailymail/stories/26083caa27fdf8ff2d9ec672ef7a5c4aec9104b6.story
# ./dailymail/stories/0935f5a15119c40f7f322c29b8a1440d181c54f0.story
# ./dailymail/stories/847fcbe17a3feb143d16a3f5ae8e48d7dffea530.story
# ./dailymail/stories/843569da111abc7ef83e8ae82992b458020e6e29.story
# ./dailymail/stories/3e4b0bd8f208707de67f324573bbb95f269d0a33.story
# ./dailymail/stories/7510623ae9572562b4a1099ba2d533917de685b7.story
# ./dailymail/stories/cedf729462a76d25d5d4cf856945bc8c87cb6797.story
# ./dailymail/stories/044c19650ec8d4d4d501045dfa9d06f38586ad3d.story
# ./dailymail/stories/ca50feb25d84ba6b57dc20e7f2378ffe43848815.story
# ./dailymail/stories/4c075f586651b77aca2e69a2b45cd783a882eb1e.story
# ./dailymail/stories/1611205ea7d0451fb98caffb3b31a13e8ccf643e.story
# ./dailymail/stories/26fe579b8b91b04cae6a70e7e89dc0aa78c3c97f.story
# ./dailymail/stories/cb9cfde2692d47ecac575e6c321afe061fa88bcb.story
# ./dailymail/stories/8bcc9a1dab7ab100a9cb21a3c5f2373cea68fd38.story
# ./dailymail/stories/8fc09c6163ce0326cf4915e447036f8d4bad8fae.story
# ./dailymail/stories/a9169d68916f89f83472407177107df763f54033.story
# ./dailymail/stories/8c70b49c5fea9a24029ef6ab5ee532a145a5b66c.story
# ./dailymail/stories/961bac593e5dd41e1d68164d9cf372393ece9a54.story
# ./dailymail/stories/4af38a40b026da7cded5d250fc3221209f71eb98.story
# ./dailymail/stories/021493816449a011165da8544cbbab2e5b3721f2.story
# ./dailymail/stories/0b1072939b9c0af0cfc29bcf92a1334630fb6325.story
# ./dailymail/stories/70f3824522a7a9d05a90d27731b7d906f8c096a5.story
# ./dailymail/stories/4f67ad416573542afab7169602778a07fa6e0e6d.story
# ./dailymail/stories/17662aac9fa4525a39bbe79904b66075a769acea.story
# ./dailymail/stories/f95c56f6e17234fdd88cc6ed8d45f2acbabf0a19.story
# ./dailymail/stories/19bd8f5918fbe3a5d7bbd0b9cd4098e9cad56af2.story
# ./dailymail/stories/898e0bdbea1d0676f51eacbd2f79d41b62242aa7.story
# ./dailymail/stories/18edbfa14ed4e38f527a105e952cc2edb65327fd.story
# ./dailymail/stories/ab234175125bf368e88270523af11a5958041e48.story
# ./dailymail/stories/9876909234769d6e2b97754f342c79d0d51bc448.story
# ./dailymail/stories/7af19e25a6a5bdccf31c16b159686bb526f2a5ae.story
# ./dailymail/stories/4dcd3007e89449101af43e269203d4a2a0951bb4.story
# ./dailymail/stories/14fe13b3d167f6439bae40b719e1b1b70c8a3ddd.story
# ./dailymail/stories/7b1bd79278c2ced9eb271a24b8911dd7147df6ff.story
# ./dailymail/stories/17f68a2c57c0f4c1c19223cc8959de338f8f3e2e.story
# ./dailymail/stories/ac1b0180881c97d9f0d57d403c0bbc21fe29dd3c.story
# ./dailymail/stories/a39bee7d20e0931704057480bb37025290652ac2.story
# ./dailymail/stories/5a87750ed8ddb8bd64bf4caf4b6bd17f0f298e0e.story
# ./dailymail/stories/dbc66eb63b2d9921171aee25070c948fa49497ff.story
# ./dailymail/stories/b8d0e3269f56d0e714214504635d22a48af635f5.story
# ./dailymail/stories/53c6e10b795d725907c21f9df9e1bf49b92e92c7.story
# ./dailymail/stories/7925702b7cbd15f8cfa4486dd8cc700b8d4b7ac3.story
# ./dailymail/stories/5ea8be7ec7747c7d2faa2e2f05e9607d1c81f935.story
# ./dailymail/stories/a75c9d998c3db5550d0ce06174d823f141a3e93f.story
# ./dailymail/stories/3fdb4ea786d9d1a43f3819c86a589c2663e8f0bc.story
# ./dailymail/stories/d7c0614f448acbe1c985a7db8e37b4ef5d479733.story
# ./dailymail/stories/b2fd83f9ce6501f8b961dc33202c444ea8de0060.story
# ./dailymail/stories/c8250b5ab814f8c93182fd63f233780452dbad9b.story
# ./dailymail/stories/3a5de978915d4f1a77283251bb124ece6423647b.story
# ./dailymail/stories/a0636a3cd67ad030c6b3aae3ecb18e6df4e73a70.story
# ./dailymail/stories/8299f18bde16cadd03f3f4c87ea35fac1bbe0686.story
# ./dailymail/stories/0ace40fc1688a63e8605e56aa484bcb49a39bfda.story
# ./dailymail/stories/7b00fe2335eb1022059c4e24befa69fdcd5c7371.story
# ./dailymail/stories/ae28c48ce274347923cf3e6c4c361d0c13d333b3.story
# ./dailymail/stories/6ca6e7da803b2c5325d8ac024d5ef04190dec244.story
# ./dailymail/stories/327367fe8a6703e4cddc04031f6e4496e6c463e6.story
# ./dailymail/stories/560833702b373c238eae1bc1468d1d789cbbd6b7.story
# ./dailymail/stories/4ad3c3afa389637686f03b97e70d98419560bee2.story
# ./dailymail/stories/efd69522ca97a6c1e947ef27b653d6a3b6dd4333.story
# ./dailymail/stories/72a1b9c0905f8ced583eb0c93fa28038d75426ea.story
# ./dailymail/stories/36030aef4c44605864c7f099b45a836da0dda0cd.story
# ./dailymail/stories/e12a6d81e715f1066c61ca63b9f01c16eb16f110.story
# ./dailymail/stories/795408f0ec14e392c92d71efeae0d626abbc820c.story
# ./dailymail/stories/c20570125295010ecd5a3fbd8a80f7638fc36fd1.story
# ./dailymail/stories/2d6449947dece18ac397bfc69120ac8079e1d8e5.story
# ./dailymail/stories/cd494df71335e6f47227a4b2e15758c524f0a5ce.story
# ./dailymail/stories/7acb05542845998106ec4c59bbc374b8cbd8eeef.story
# ./dailymail/stories/7b1cb0af1dfebee6a6ef2b03f4ebbe0e239c9208.story
# ./dailymail/stories/0999944a46e0f97c32190992c81aaaa170e939fb.story
# ./dailymail/stories/a6f16dcb93bfcd0624ffa469e8fe9678d1d4a595.story
# ./dailymail/stories/bd4aaa4209196fa99af6f98d9a593423e3c4623e.story
# ./dailymail/stories/dca1c5bb4ba499a361ee175cf3e301c71e974ed4.story
# ./dailymail/stories/d99d86db20b59d9668c99a1e41a108a43da2af71.story
# ./dailymail/stories/e1499e755013fbfd05912adb121c7c9223bc4e16.story
# ./dailymail/stories/8bfabe6e8792695a44770a4d7690f866f1668d02.story
# ./dailymail/stories/9aa4ce8ea0c754fca2c074e73b9bf523afcf9efd.story
# ./dailymail/stories/ac4c516da1ddbf17dd3e57039bbe83d5cf3a09c8.story
# ./dailymail/stories/bf0bc80e0da81dfa959003e507169a46e3c55d1b.story
# ./dailymail/stories/f2b57ae4351196a4e60c0f5f0742eecbaa983345.story
# ./dailymail/stories/b4148969d817a8d2a2ce336eec737e75c651aa27.story
# ./dailymail/stories/887e4e776c00b8e79726e1745eb04e8e6e166811.story
# ./dailymail/stories/d21fd5f5cbff670edfa338ab35ff789a077fca44.story
# ./dailymail/stories/8287d21273bcfa037851edd90536205a5a863a0a.story
# ./dailymail/stories/41bfb1d1837a7e362626ce55fb3c9d39423120e3.story
# ./dailymail/stories/b39341c062db854a18fefb0f100976103705a086.story
# ./dailymail/stories/18c1e48749ff9967513119de7185dd77a8067d8e.story
# ./dailymail/stories/2090bc4d8d1ea211b2398119b9535c2e5fb4e69c.story
# ./dailymail/stories/7e9799718b0fb720a0d601de566e608068f7122c.story
# ./dailymail/stories/f26cb18249c9d11936a39a250f9e354742552135.story
# ./dailymail/stories/908b9fd282a829f7c648bf6d643c14cf7d31b6ec.story
# ./dailymail/stories/7015e5acae78222fbab6c30293a41d05f551994e.story
# ./dailymail/stories/e559a6b1f44d11afe2de7a3fe217d0f5b36eb970.story
# ./dailymail/stories/7fe154b6225b80db362485fd864b4f090c8b1e8f.story
# ./dailymail/stories/89482fdd08a2e9c3b380637d6bde5cd35950eda3.story
# ./dailymail/stories/81085096603cc528166dbe0db5a0fe5f0135171e.story
# ./dailymail/stories/92ce51c6b1b29712bd8561dd20e5677983157376.story
# ./dailymail/stories/30d799a7baae0958629271a3c33e6de249fab754.story
# ./dailymail/stories/643db2ae1bb051812ed21c1f9db14c177878e92b.story
# ./dailymail/stories/0eb6129fb4ebe7312f0cca0a39d20a3e68b928fc.story
# ./dailymail/stories/a5abe15486a593195eabb8913c1263eccf5b380d.story
# ./dailymail/stories/953f3d50c66586bee9e494acd73bbe724d73f72c.story
# ./dailymail/stories/3ef334f314a0e3f4e66e086a7e2bf279ad61d533.story
# ./dailymail/stories/ac3d1cc7a032fffe9d7fa043cbc6b23bd3f8aab4.story
# ./dailymail/stories/cec759716548bc34ef6ddbfa4c06a4cbfa024cf6.story
# ./dailymail/stories/7b37f1e67425f66e3db2add63a3f3b4a0784387f.story
# ./dailymail/stories/a652cf92e24ea2bc2e9f5a624b44479153f9c727.story
# ./dailymail/stories/16b22d0148fef4baa24dcc330b6ac81a363c0f1e.story
# ./dailymail/stories/214eb04f600dce64202b3c1eba84e86874a2641a.story
# ./dailymail/stories/4276c4e7af6bee6cc82708b49aa79256a074ea11.story
# ./dailymail/stories/a2597f2db4bb9e5cab4c1b08d43c5c1850de2c1e.story
# ./dailymail/stories/868be1a9da96d8ddbc357599943293a7684eb271.story
# ./dailymail/stories/55bf21206208fcf26e349f459abbf2b5eae9b362.story
# ./dailymail/stories/3627d0322399cbe7396152a9c425cb80706c477c.story
# ./dailymail/stories/a8d675b7c262c0a6e1a7f4684a91accf14f7e32f.story
# ./dailymail/stories/c88add9e683d062076a515949ea7b838abdf1331.story
# ./dailymail/stories/db70c5da7176a7dd480d0fd4a3dfc2cf241d3a37.story
# ./dailymail/stories/f5d1230f1ef1d26dbdc2c4301f3ba7ea7e8a0c9e.story
# ./dailymail/stories/1b84929a0acc26b39c12a91c6fa01ce782c569c7.story
# ./dailymail/stories/17b542cd43b771069ea5ce34069ec60b35aef1b8.story
# ./dailymail/stories/26ec8708dff5d299ebab655973db5bd0f8dd31ae.story
# ./dailymail/stories/151a2a380771990537cd31c1882b6d25a43dc075.story
# ./dailymail/stories/edde10e6f363ca41b2440d3e5fc1bfb346b43798.story
# ./dailymail/stories/6579a1dcc1cae2a8203c8c96c56a00894450b0c1.story
# ./dailymail/stories/b61a9f8509e9a41e35b19b5b9c02ae98bdec5e9f.story
# ./dailymail/stories/10bc54766c8de1b00769417a425345b2a46c1141.story
# ./dailymail/stories/361e43134e11d36a4c00862b1ccab088a2967404.story
# ./dailymail/stories/2b4accdb711145b4e754e2aea92a1bbb594c90de.story
# ./dailymail/stories/a1363d62bbe7dc8dc85c9532e167911315fcef45.story
# ./dailymail/stories/d55beee41d21acd7aee0c55be8a06f72c58bdb07.story
# ./dailymail/stories/1de4c54a655f2fca583816fce94b3a6b7f82b99d.story
# ./dailymail/stories/986964b0b681817f432cfe7ef190d415f104c039.story
# ./dailymail/stories/a5d726eb55e4d4e70e966d9b69990c43771522ec.story
# ./dailymail/stories/b2ea557d2f4ccbe36837fcb48b754ceb03088f4d.story
# ./dailymail/stories/c8a94e7d92a992a83a76ca3c62c02c08ddf0c587.story
# ./dailymail/stories/124c22ad88eaa8589343587b713b45863c48d783.story
# ./dailymail/stories/606634ee9c5ba5e4abe3f069bf932cdc9b25892f.story
# ./dailymail/stories/9c531fb73eb3130322cd80b669c8bb5baa886e7e.story
# ./dailymail/stories/e675b33aa19962539b39dae8e3f324d7dc0810a5.story
# ./dailymail/stories/3f4c850752e2822038844ea7a0bc467b4fe224bd.story
# ./dailymail/stories/ad696a5178f453a1dfcdbd42cdfdd9cb02e2ab46.story
# ./dailymail/stories/13fa845f35ae4d82172e803cfb02ce3ab779690a.story
# ./dailymail/stories/c88383958e9ef3f84649583bfe4e64bcd0629c72.story
# ./dailymail/stories/9cc6721677443a0d3e8c61eeff14cd75f884ad5e.story
# ./dailymail/stories/1566e5e2bc5c78f4ffb029f179a5a41eb3001537.story
# ./dailymail/stories/9d8e79503bac876b96eb4c7aa91c542bc0ab8ca2.story
# ./dailymail/stories/0a2693ea6d1d636b7961b9df51d14d0aa6cc0885.story
# ./dailymail/stories/eb2e94c0f67e1104cdf791e06ffd154e36d91ce2.story
# ./dailymail/stories/a3fbaffd485b4dc8d4a3ca9f6bba1338876f2df2.story
# ./dailymail/stories/a2e269938a1eb3b2e52761c5f188248aef3908da.story
# ./dailymail/stories/b88f172c45e03935551263fa3b3dfb086a5f1c24.story
# ./dailymail/stories/b185b68c83a9f1c3fb8619451f212a599fb77d2a.story
# ./dailymail/stories/c0daee326074c44e734bdfedc0ab170a199733cd.story
# ./dailymail/stories/9fd8a88988e9cc2771f302dfd8d4dea61a3d2fcf.story
# ./dailymail/stories/766f281ccfb475b6f58e16ac28e33746b4581fb2.story
# ./dailymail/stories/0480240ed2b19bd6d6cd9f9bb4f6026a59dbbbe3.story
# ./dailymail/stories/28fc132016f1d228dabe34240cda32b16993c4c9.story
# ./dailymail/stories/b46a4d2a0723a9ee139b82c5fce76a54054d8cca.story
# ./dailymail/stories/ce78e90d2a0d53113d5bc6cf3d1cac297ef055bb.story
# ./dailymail/stories/9c5c94172a4711dd6b0f7d03889ac78a7bc4df80.story
# ./dailymail/stories/16d20dcc763c89a01c1a7683429d5129a01ea519.story
# ./dailymail/stories/36bbf60a1f8992d391a295d71249afc6899a011d.story
# ./dailymail/stories/a635482a359e20d25b776afe3680d0eec0ec71f2.story
# ./dailymail/stories/a726904222fc9e3d5d59b88c562fc98eb8a7070f.story
# ./dailymail/stories/dccea4bf74c0572869beb8c91dee995ecee98cfd.story
# ./dailymail/stories/3b2b6b9b7284394cccf84b0b6b736ce052102ef2.story
# ./dailymail/stories/e6307552428b46aa2dde21e048819dff3429e316.story
# ./dailymail/stories/b009b63dfb687e54e63b3752140a6cb6927ea980.story
# ./dailymail/stories/57bad62c610754c019aaceed38930ba07cdf1656.story
# ./dailymail/stories/1c4119b105df1dad90cc752e5e16a1d129f24306.story
# ./dailymail/stories/499d494f323fea2b526365d327ccf94e8fd5601a.story
# ./dailymail/stories/22a3e24079794b1b6cae43020936824c9832c63b.story
# ./dailymail/stories/c8cf9bb7d91fed21389786819e22ab4ef3cee338.story
# ./dailymail/stories/1fdb50e2b3eb57ad573b7e82bcfb1203cecb5808.story
# ./dailymail/stories/ab43cb24eeda1ca9608911d2a209ccf5f26eacd7.story
# ./dailymail/stories/85f72929a0cb62ae5c9eadad3933d345644a8afb.story
# ./dailymail/stories/feebbfb5645b9a6a783a5997bec636d74c31e013.story
# ./dailymail/stories/ff49236f167909baa85ef33bb2097b361358f62d.story
# ./dailymail/stories/0221bc000ac5b9537d8c91aa002035d3bcdc6927.story
# ./dailymail/stories/05ecd3a3c105953e770506b37096d9b7ec01c6b8.story
# ./dailymail/stories/102f9277e3598a7275b86516dfc5118111c9425b.story
# ./dailymail/stories/2a17d4913f9ec873cb47b531972cd3dc63dfed3a.story
# ./dailymail/stories/8306cb5759ce230ea8a45cbdd2a3ae7e8a4d421b.story
# ./dailymail/stories/eb7351741e625495526ef41054508d794b20e71d.story
# ./dailymail/stories/2c8ebf17842f22c04e2df490b1ec5744b12ed305.story
# ./dailymail/stories/5cb9d4d76b9f1e216f1d32a8553a5d026b4cab11.story
# ./dailymail/stories/ebf689e1d8f62257575a1a7e71449a1f0a727616.story
# ./dailymail/stories/7bbd1c5bdc5c166064f94fb27ffc4865a0dbcacb.story
# ./dailymail/stories/859a32ccc15fe9bc475cdeba40b545cd5d19f394.story
# ./dailymail/stories/13fb42e1a6218b3b756c7906022a5f332ba2932d.story
# ./dailymail/stories/37c6e6095b2283af35145f46f1c71068699ad7fb.story
# ./dailymail/stories/e0203a114d1bbe5a1da25b8c6b58cf5bda50b25a.story
# ./dailymail/stories/d50f713caffe87f6d26d452d6b24af756ac2a0d3.story
# ./dailymail/stories/4da170aa5edb6a9649e86ebf04bcb23f669703f8.story
# ./dailymail/stories/2a540be8ef4ae4ee15b8b2c8176b2a01c5e20977.story
# ./dailymail/stories/4644df2fd913499ec52860d29a6ed1a7d5e1b3d2.story
# ./dailymail/stories/8927d2394e503eea3262bcf3d9a92aa841b35c76.story
# ./dailymail/stories/25bafd0f9cbc1572ca74367cac7d8c32c0621c7e.story
# ./dailymail/stories/798a529fdcee0a61c9abd2e14d0af68d5dd9da77.story
# ./dailymail/stories/62844962efc2c29f692606454ac355a40ab445fc.story
# ./dailymail/stories/fb083e1093b48d19e749e10dd3ae91f4894f479c.story
# ./dailymail/stories/2d4593595f6188bf717630d64f771e4ab05549e8.story
# ./dailymail/stories/b7c38fa10c71fadf25b0dfa7cfa1e471703f0390.story
# ./dailymail/stories/ad5d026dc7c998d600b30b966d25b932b9631f81.story
# ./dailymail/stories/07f3d8c1dca494ea281f2ec843ec730218db3023.story
# ./dailymail/stories/ed1f39e9af5522dc527884562df7b99681523cdf.story
# ./dailymail/stories/8b59ee002241e9d71ee828201f6daac93a7b9e5b.story
# ./dailymail/stories/5ef44028977417e553f4166636d456555d9ca4ad.story
# ./dailymail/stories/7baee38ce0b4663e9bd0c006f5b1803c58d314c8.story
# ./dailymail/stories/71c4060ad10886b544255d7b6a72e720a90b4d89.story
# ./dailymail/stories/e490399b821a1165732e6e6682b09c288fcca229.story
# ./dailymail/stories/1c74f4538a9352cf35090904139b6c40f30769f3.story
# ./dailymail/stories/76ce480d75ae2f6391daab495762a2b8852ccad2.story
# ./dailymail/stories/40862bfff85c78e373cc172bbde937224dd6d181.story
# ./dailymail/stories/077af6a33b8cd89ce1334c08a6b27a0d721623e1.story
# ./dailymail/stories/6ec9f842d0b8360dcaeaeb50c0e7930e994a29ae.story
# ./dailymail/stories/c5c1e5107af6856ae568de3371ade511ea72a6ab.story
# ./dailymail/stories/d79fecb09db177001f4b4c28f2449e1569346d4b.story
# ./dailymail/stories/f496c8a4bf47ee5a75ad79ae24c734ef5ae7b7fc.story
# ./dailymail/stories/c11d14b507f5cdd8bc6d6dbbe93f194d22f9e4f7.story
# ./dailymail/stories/e9a49c1fc51f79f786463341db8065c95f5bff44.story
# ./dailymail/stories/74ff9cff6599f7df173a5abd8b20b380e6d4d697.story
# ./dailymail/stories/d6e3537ab468f16819b7d4de4c23a8c4bf156287.story
# ./dailymail/stories/a87f959fecf80f092d05c582a515a89d1241ddcc.story
# ./dailymail/stories/70490801462b9429957244dc2bb66638a0e1029a.story
# ./dailymail/stories/f9002c8971cebd83733848cf204bb072e07f3b1b.story
# ./dailymail/stories/74468085fc39beff388348bd55cd02e6aa7959ba.story
# ./dailymail/stories/157e1beb3454a1611746cce00cebf663b583a08e.story
# ./dailymail/stories/113e651a0a484955a0596662185587e648e5ee55.story
# ./dailymail/stories/1a26e244b2fac7a8f5dc8cb4a8ad78f812b60c75.story
# ./dailymail/stories/40d244acc30955bd97848a0630f82e6e99a44f9a.story
# ./dailymail/stories/77d9f43e5feb57c12e329877f175bd92946fad11.story
# ./dailymail/stories/ff812aaa593ee3234ed90f977f487b97c0ff3d5e.story
# ./dailymail/stories/3e89db8d2a51ba72e9c0ac344fafa756e438cbde.story
# ./dailymail/stories/70a15fe09409114ac9cd5030b72ac3b560bef57d.story
# ./dailymail/stories/2b35edd7ebb84f1253dbf3f9d25334a87ff85d23.story
# ./dailymail/stories/9beaaf73e4517d5bf1bc284f386485d571da96cf.story
# ./dailymail/stories/81b3991558b4cb25d860062ebb95ac73f52565c3.story
# ./dailymail/stories/b02a32b7b42d72665f7326080d80a2c0911fb7de.story
# ./dailymail/stories/45574ea228a91c411c3b32f47c319fe5db86eeac.story
# ./dailymail/stories/c47392d90af2ba30ad8e5db53c4afc70fe55e1ba.story
# ./dailymail/stories/d11ecbcc828403caa6d356def04c77b373de4459.story
# ./dailymail/stories/582544544cd05245b336faafcfc4f33e45489644.story
# ./dailymail/stories/13f43cdc3311e9db7a3a429c198f5a5f8a24bf66.story
# ./dailymail/stories/6d1ac68ee63197991177e7ef3dbbeeb930c0e748.story
# ./dailymail/stories/91a0bde20f9b6320bc2cd7d275853ebee57df051.story
# ./dailymail/stories/6f5dc4913601253211158252e5525b0f2e92c071.story
# ./dailymail/stories/c868a8a1eff7075416a52a9d1182fde442411b9a.story
# ./dailymail/stories/b275abb5742081ed6214328944c8cf6c61b05137.story
# ./dailymail/stories/48786c8e9e3a6d066c4189843bae318ec614bb2b.story
# ./dailymail/stories/efe143fc385f4739389dd30fc54f8692c76bb020.story
# ./dailymail/stories/40f3237724cf071faf5be3ad5deffbd54e31ccbb.story
# ./dailymail/stories/a51a16b991ee0c2dfe23ada6789274342d297c11.story
# ./dailymail/stories/f9a1388b5b53137213362935f02460a57d8cac33.story
# ./dailymail/stories/0651c529fad57729b9305a089dd1aabb5b562954.story
# ./dailymail/stories/ef15b8dee53283f504d231fbbeb722b03462f3ab.story
# ./dailymail/stories/0a7803361bac620ce6539cd776bc2c71152f03f4.story
# ./dailymail/stories/89dcd1dbf925f462052ee2f6aeee4cffc0933c10.story
# ./dailymail/stories/72b3eb2d3a8ceb009ea5dd948fca55040d76bd21.story
# ./dailymail/stories/2357509b6e1c85a9609dd0617e392bb17f963e7b.story
# ./dailymail/stories/9ce7d85d97b8d75d99dd0b2da835738338d10b3a.story
# ./dailymail/stories/356cb1fe59fc7d44342381777614cba30b7b75a7.story
# ./dailymail/stories/02cde45e9fc829ab2080f0899068e35ccd738984.story
# ./dailymail/stories/c63e7e57773fae20ca99d77cc72213ae423c026c.story
# ./dailymail/stories/29df27b24c2e2149e92fecb8b8d9350add2f74ec.story
# ./dailymail/stories/770784100d8604e5d9de022d45d3a3efeeb11570.story
# ./dailymail/stories/aff83ab38fe2cf68f3c9700af8a8af47682f74fb.story
# ./dailymail/stories/3300a26b80afd7856487c689acbd6f7c4ec44bf2.story
# ./dailymail/stories/57e262083d09728c3569b3e912027f4c072a5536.story
# ./dailymail/stories/121287192445e62bf94bd51242f55a67b0b3007f.story
# ./dailymail/stories/6f7ff9f7773657a5944758ebf96842c09445b7f5.story
# ./dailymail/stories/3769c7950127544c2c351e1b58c951cbd0a132db.story
# ./dailymail/stories/9441266609a17fc38c5190c89d5e98fe0fc5dd6c.story
# ./dailymail/stories/a4dfb18d881e6792f32e45af6d44722e4ddc00e9.story
# ./dailymail/stories/b33a427e26b9b92e2f2c757bdfda257181a8684f.story
# ./dailymail/stories/298b1537b23bf9f39156dfa648bb16f3416b75c5.story
# ./dailymail/stories/23ec4f8029ed6ebef623b7aeb8f39849712ad114.story
# ./dailymail/stories/88c2cb70d801e8c03cc2711d6072e66f97f5f73e.story
# ./dailymail/stories/4e2efa55a78577edc4dc63398dd4c73b77109c37.story
# ./dailymail/stories/044bb9b3977f9d0b82afb4731ae9f94ae9d86ee7.story
# ./dailymail/stories/a51f07bccd848d97bda981913edb974b12cbefbd.story
# ./dailymail/stories/d5db0be72a7761b84374896fece98f09c3f385c7.story
# ./dailymail/stories/8d540d6a10f3e04468c78f51ae39fb586b7e7b7b.story
# ./dailymail/stories/6956586c34533df0122d2cc32c9a23c00ab5d291.story
# ./dailymail/stories/d862d9da5fc997843e80a600fa7efba29c59e1fd.story
# ./dailymail/stories/77fd778de39da53aa0e552980fbf26a6f8c7f502.story
# ./dailymail/stories/a2c4d02e38535d50f8a3d35f2950df9281d12f99.story
# ./dailymail/stories/ba46dd0c125727c1cb5521c08ba7c526c28a512d.story
# ./dailymail/stories/edb78a4f5217e0f2d6745cf3c40fa1fd5a28442e.story
# ./dailymail/stories/1e74feacccf8239a6cd711153e35946d70986c34.story
# ./dailymail/stories/532e2711ebc5d21eeebb4abf0513d11c2f54c567.story
# ./dailymail/stories/e4bae5ea6c016f5d2c608a2f9c7bf202f853c660.story
# ./dailymail/stories/04c0632f7d4f97f58d80fd580a13da591ccae29e.story
# ./dailymail/stories/3c4cb143b22f207c2de919d985f6144ee1e221aa.story
# ./dailymail/stories/a501f42f5b5b3ac22a7f283681f2529974a7035d.story
# ./dailymail/stories/4fd303aaa415e7d70c3a9e135df0c28dbd1891bf.story
# ./dailymail/stories/cb828165c7e801450b9af805888e12e568132f13.story
# ./dailymail/stories/ba6bd27c2351ee55746bcc913a83bfc77df77778.story
# ./dailymail/stories/b70a1c927eb8e3d72fa8d45be35f0d0da3953839.story
# ./dailymail/stories/603698ad5340fc4b09b3440831fc1a86343ae41e.story
# ./dailymail/stories/4a04d822100c0a4b22d6a8f6e26ef159233662b6.story
# ./dailymail/stories/cb5c0b2cb32e900df7b5ae2b477fcc23f713e442.story
# ./dailymail/stories/719cabddb2815d8a5c3fc5d9f86394f07065a3f3.story
# ./dailymail/stories/449c9766e02a6488609f17ffacfe80c5ae56872a.story
# ./dailymail/stories/221d8b6d8b268450a593572b54a4c9a826fa1cd6.story
# ./dailymail/stories/98bd1db2ee0ccd835da9e71e7b6fa2be9c8a9477.story
# ./dailymail/stories/deb292b08eccb38e4fae58936358a113ddc80c4e.story
# ./dailymail/stories/41a1292df7b448aac6e3a61adf42347c1fae7864.story
# ./dailymail/stories/e47de018c83a11ba12e654ed150712f5e6932b12.story
# ./dailymail/stories/5a2c3c12b88fb5ef32e8053e92ce6b79f7011099.story
# ./dailymail/stories/0f55c6e8f1b7952ddfa4792b77b48c374402db8d.story
# ./dailymail/stories/2c8b478dd17be5e7257b1bcf17abbbc755fb8cb7.story
# ./dailymail/stories/6a54c9240c2b7e2598e44ebb4b834be5296b83ec.story
# ./dailymail/stories/bf9150235ac34f00e5ea0dbd299c2cd94b9c9cc0.story
# ./dailymail/stories/c30151df9ea0a14e3b2195f789f64d14d0cd9d95.story
# ./dailymail/stories/4895a86e3f492ee2ebd8377c94cd3aad3c8bc7a4.story
# ./dailymail/stories/5bc1a49006ec27b526d53e987d8f7805f3827471.story
# ./dailymail/stories/b2e0d761aab8a60c3b230ca8d991e8dcfb721ab3.story
# ./dailymail/stories/9becd148d4ca5618fa57bdca4e8623b11b32267e.story
# ./dailymail/stories/0f3d8c65a611881e9863d19d55e8339bc81e12b8.story
# ./dailymail/stories/160affa04d377e82ece1ef2c4862a79f427731ea.story
# ./dailymail/stories/88e6a8eafccd4dc7350b8288e345a18378be567c.story
# ./dailymail/stories/6e2c1d2475bdc8239eb9802775cf9cab4b8738d1.story
# ./dailymail/stories/faf5a752ae42c7e325f93cebef744e02338a9a0c.story
# ./dailymail/stories/476135c1771b664cc368bd6ec0ba70b384befaf1.story
# ./dailymail/stories/0b025fc57380060743ffa17399995da1569a614e.story
# ./dailymail/stories/eb6161462b31c85d146cb01100a5f4fbb443a230.story
# ./dailymail/stories/df7955592991bd18c4b929e6a39ca880cf372b62.story
# ./dailymail/stories/82c0c27114a02c33e52e12b091a50343026abfbe.story
# ./dailymail/stories/9437cdfeaadb3c7d88b177c97fabc1b7e8a1e217.story
# ./dailymail/stories/32ef10e17cb80d4dedf2a1a321caaa9c7180696f.story
# ./dailymail/stories/f278bc3aa1a3e6656c03545d54fa675212cb8b85.story
# ./dailymail/stories/71b1ee0be6310b52f235b646950b4924a1140fac.story
# ./dailymail/stories/ecc7e24e1a3cc68cc8a87f951c8356824913a4bc.story
# ./dailymail/stories/6f739a1c6cd46b621ce0802bc80993bda29e3566.story
# ./dailymail/stories/ddb31c6eda445db91a0e859a59412df0cd8d056c.story
# ./dailymail/stories/c0f2f29866b4c87d9a53fbd3fb729e6b8dd92fdb.story
# ./dailymail/stories/f257daf10181f7152abe33857d064929a25e5ccc.story
# ./dailymail/stories/8a0881c7bf0f9979054a087e2e135e86824e19ae.story
# ./dailymail/stories/f15e084e946b47151b3d358d28911618efbdef4b.story
# ./dailymail/stories/cce7660deb45b1788b54d0ffab2e5e9e4a332cb0.story
# ./dailymail/stories/4ee59a5bf1eff5d448dfe0e9057782ba4beb42ba.story
# ./dailymail/stories/4ac4e830ded76b1713892ab02f39c5579de5b4be.story
# ./dailymail/stories/330ff56db53cd52c65d2ce9219ffb398e6ccbe94.story
# ./dailymail/stories/45980ea3b2f660cb08ab73892a5e763c2c931c11.story
# ./dailymail/stories/38b983f9d0dd3db05ceccf6b4762b0b49e1813b1.story
# ./dailymail/stories/bee40903cf13f6565f982c903b2c5b43051ad298.story
# ./dailymail/stories/c1162ae920da18097cca6e8d9520e6d9411037b1.story
# ./dailymail/stories/77db10f5e235f5b359495a4ec1ee639d002d6048.story
# ./dailymail/stories/3b8dc47341aaf9ff355c73be3fae2fde8363418f.story
# ./dailymail/stories/7115a62349535f81ed8eb1693fba10b593c87680.story
# ./dailymail/stories/c77e9da5c7c54ebda079dc8e1e84f66b2b062fa9.story
# ./dailymail/stories/349d234d54b5414976bef3185b9a5155946118cd.story
# ./dailymail/stories/9871bd56e95c540e049be90fab4a83b0ff8d236e.story
# ./dailymail/stories/3ad857d091bbcce28282728384d8c34b8fd1a071.story
# ./dailymail/stories/de8aa520bf3b91bbb4ac170db4a8634838b8b31c.story
# ./dailymail/stories/d3bee21d540685aa8b6ce4e87edd47c16ed676c1.story
# ./dailymail/stories/0972d22d5b1b156e4fc69bb3af0a3e7ecb6d7d9b.story
# ./dailymail/stories/a81da87ad7c133914a020fc176fa849463b40d4a.story
# ./dailymail/stories/4c64b5f175dbdaff535a6c9b48213dd30ad3e3a4.story
# ./dailymail/stories/ac43d20a171d61c0439061a3284ea854f8ccf1f8.story
# ./dailymail/stories/bfcd5994279e1717bd7ad077d625343b5fd37d4b.story
# ./dailymail/stories/eb3f1e721c0189a395db9c8d670e5e75b54d675b.story
# ./dailymail/stories/2b6b8c898a65c2ef09e8b1409d0aee30c830468f.story
# ./dailymail/stories/fd395a0c07b4f625bd3886b0b6aae6895ccdc08d.story
# ./dailymail/stories/e115cee38dfd405b35a0cca1fc701d631adecdf4.story
# ./dailymail/stories/1af37372f2cdfb45c1f0ced7b4b29e9c0fd4e7e7.story
# ./dailymail/stories/93204aeddaded5456b99e9ac84539955af2d772f.story
# ./dailymail/stories/157e63aee4ade54c0362b6f5e35783b1bacb1986.story
# ./dailymail/stories/db008350888751a56bec0742d61b870f32821185.story
# ./dailymail/stories/7c0d2467986e4e8cf55269e7d3b7e8cfa44b1abd.story
# ./dailymail/stories/087cdf4688a2d165733f6029753c402cc8bbe907.story
# ./dailymail/stories/149e5b0b61e740b6a83c585590e8f2e966403faa.story
# ./dailymail/stories/904a18b6ede267860bbbac76b1a83883f926857a.story
# ./dailymail/stories/ede974f527ad7614d7c10eaed5900ea413c6f559.story
# ./dailymail/stories/cea375e8a864675175ca5a69e576cac82b50fb99.story
# ./dailymail/stories/f559c6106e4593549a2f3d6737374c4e2be1f521.story
# ./dailymail/stories/bf85c7da6219ee05a63dddffbe8a0b2e6a7b3333.story
# ./dailymail/stories/4e0bf4db8a96819d20277ca55bc8aa329ccda4f7.story
# ./dailymail/stories/4fd3cf98fd0a082efdc0e51684f5e156c5f8639e.story
# ./dailymail/stories/da80b70f4996ab5a86d5c743a540ea091bd45358.story
# ./dailymail/stories/6559748e1c5dac470776d1ffc842973830d81da7.story
# ./dailymail/stories/62082303c16a2aa5a923596e72dbd1a7c0b228b8.story
# ./dailymail/stories/229a900c1ee4bbaca9abea1620e660e7494f84bd.story
# ./dailymail/stories/8bb65fa34617e88ab97447f6bcb7730765b30d37.story
# ./dailymail/stories/2ee60567015401037dd1b6681984fa4b15cc663f.story
# ./dailymail/stories/5b5fc921572c7ecd2eefe7e39770a971902e781a.story
# ./dailymail/stories/409d09b6f4fd76f82f1f79902bd0da80f64b9bb2.story
# ./dailymail/stories/6e5b1a240c3e9f44eb0e1a1ff77e487e0636948b.story
# ./dailymail/stories/bc721db319cbdd6924537aeba7efd61619422d49.story
# ./dailymail/stories/0311d8bf58432a708d9f993b9379228f994d633e.story
# ./dailymail/stories/4ba6d25b4fce919c1475ab2823da3c6b3499bb5c.story
# ./dailymail/stories/7a062d1b404fc984c796a29537a8355b418c71a8.story
# ./dailymail/stories/0f27744394035dede5bacc48d394dfc044803212.story
# ./dailymail/stories/6c6f1dbdfc249d1e9a684c4ff22607d117027f2f.story
# ./dailymail/stories/b955f7a918fe446c97fd8028e4fd524172a7b5e0.story
# ./dailymail/stories/8865ef9519a810c335ae76ab8ea7e0f0b6b3b730.story
# ./dailymail/stories/02c232ef55d64e86a8f16c220d4cb8269d7731b3.story
# ./dailymail/stories/de6cfb5e356b0450ad58485ffe5dd4418df2924d.story
# ./dailymail/stories/37d8ef2cc7c7acb5bbb7f98d66d873d30d4859b0.story
# ./dailymail/stories/0ee1a8578be918631e8ee479acd6602043e179e7.story
# ./dailymail/stories/809ceeb0a64841f31128384ab5703af4e3a2b9b1.story
# ./dailymail/stories/720e766e1018ca53756757f11e4c27aeac9374e2.story
# ./dailymail/stories/9cf853cd50f1d6f56305d259df9995a166782f97.story
# ...
# ./dailymail/stories/ecfe0d8aff00c3036cbef759bf99335f68f5d03d.story
# ./dailymail/stories/614d98bac159f366860423f34fdcb303d13dbf0c.story
# ./dailymail/stories/2059c7857d0d456a01bca2936dce366b65dc9132.story
# ./dailymail/stories/3637fd20826cdf99cf16362d2ee8cdaa94967a0b.story
# ./dailymail/stories/827c7d4bc32124d053919529cf39c1703092c9fd.story
# ./dailymail/stories/8c36c8a6e8e3b7fc2a9322a4a6dc88f046389fa1.story
# ./dailymail/stories/3543fec61fb468c9fceaa558ebf576bf6501c169.story
# ./dailymail/stories/48bdd0646120dea98c0eb35136135755ef1d47c3.story
# ./dailymail/stories/53bd01983a0d02ca8689eead1789f91f1f2e342b.story
# ./dailymail/stories/143d7bdf88e44f27cf2a309e09d1583e12406344.story
# ./dailymail/stories/12670e6af0ccf95cf8de50f651f0fded33d419b0.story
# ./dailymail/stories/8118b9edd04d186bad7c78effab36d6fd7c1501e.story
# ./dailymail/stories/077936616bddd81b17f243dda9ebd6e3e133e69f.story
# ./dailymail/stories/87fc96df318c8bd4e272be2ec5127b9984dd37b0.story
# ./dailymail/stories/e65404fa6c74fce20c555a718747c08a50385260.story
# ./dailymail/stories/fd1941a7e2773f0eaf63f1a943987607d6e68b29.story
# ./dailymail/stories/919e6284ad7e39b29f4e3aa3bf4cbb7277fcd5d3.story
# ./dailymail/stories/ca33ad5cebb907548453e1623467c4e082ad8c20.story
# ./dailymail/stories/7b594392b5977ba72bd1faec3c79b38784670b6d.story
# ./dailymail/stories/e78ada41819b3438e313b74a8029c91124f73aca.story
# ./dailymail/stories/1dfc9d8041873bc36b5ffc4ea6ef344cd39cd2e1.story
# ./dailymail/stories/41e0b17432cfb4cdca53c98992b103c7bdf7be4d.story
# ./dailymail/stories/b45921d582facd006e0610fa872767b30fbb3b5c.story
# ./dailymail/stories/b885ff5f38bc5c2e0bb2d6ac4df1def65b73392a.story
# ./dailymail/stories/588ca87bfc1312c18331d72da7d31e4442c4e685.story
# ./dailymail/stories/d880f8d7c6e90e7726bebb331d64f9d1d3049191.story
# ./dailymail/stories/4a6d82a5101734f2ba7b00d607121e7f488471d4.story
# ./dailymail/stories/4d5ec6d5dbac35d1956ef4369aa6003abc920221.story
# ./dailymail/stories/a3d8942def42170614720f6322f80fe06a9359e8.story
# ./dailymail/stories/7527340583e3261412fba69d6cbfb69bd0f44e7c.story
# ./dailymail/stories/08ebec1cc4e1a4b306fab54c13cd5aa9ae585abc.story
# ./dailymail/stories/8c647f970ca1d23d2bae03bf816a54e984bffc5b.story
# ./dailymail/stories/badde2095825e2ce8d2e46fa17b3275022efb16a.story
# ./dailymail/stories/530b222090eb7272173578e080a9e5d70a1de515.story
# ./dailymail/stories/8dc77eed14625df596d9116226501c62d023392f.story
# ./dailymail/stories/7886861d15ab9bb2d180b4dc36d63225019f51d8.story
# ./dailymail/stories/38f46f9d589f8ba8e727d7edacdf77ee5399c411.story
# ./dailymail/stories/2b395dec93f2020f432d2acc75baecf56ad7b947.story
# ./dailymail/stories/e14f24d280279a27265ac8f928c365a3713f0758.story
# ./dailymail/stories/6e1612d6800879b1e894b6802c8908c735f78527.story
# ./dailymail/stories/f24a009c68e2a13753eccb295ead417f97891d4d.story
# ./dailymail/stories/bc060f808c328294e4998e85aa00eac30cefb4c4.story
# ./dailymail/stories/af56e488bc03416d805a602b867abfc75567c507.story
# ./dailymail/stories/5a3209d1e40d17f51ce447f56d1c136ea7c3e204.story
# ./dailymail/stories/c1743ab3f030aebc0090330c937a0ecb5b61b604.story
# ./dailymail/stories/37fa24ad05baaaf7ad36547e79a6d7270e7fa14c.story
# ./dailymail/stories/1850739dca6fe287a0e53946de4bd120a683df77.story
# ./dailymail/stories/9ccaf250a0d165f169df1dfa3ff6332fd6b46d00.story
# ./dailymail/stories/3bac95b72adadaa4335f6f1185714eb76820d7f9.story
# ./dailymail/stories/1e95d361f4c229108be87ce0f9319a4478dd1e81.story
# ./dailymail/stories/79b8d3a8ab733f3800885a5819ac9343ac4d1565.story
# ./dailymail/stories/e632803643a9a50a30caf61e77033d22f4fa148c.story
# ./dailymail/stories/47312d43c3adbfd8a713020d7e96ad08646a3004.story
# ./dailymail/stories/5842923ef0e332429f5e5ee8bf7d3110d47a067d.story
# ./dailymail/stories/9d2c1e830f3b3287b92355b593a58b02af347a59.story
# ./dailymail/stories/5ff090272dfda8385b1a95a80ea3f2f88ee28df6.story
# ./dailymail/stories/1e9d12afdcda5b927027a955bab6b2adc70c81b1.story
# ./dailymail/stories/2769230ee5e895ed80a151c9085afa8281ea1fcf.story
# ./dailymail/stories/832b6d3a88cd4aa703f98a5294b43a501c871b03.story
# ./dailymail/stories/1d89755a110ab5cdd90d1e16f55848cc3ec4b3f7.story
# ./dailymail/stories/99cf9445070699b6fb3727ed7809a89ec026796d.story
# ./dailymail/stories/0207f7f2cf08dd120ecb5621608f27720e05b198.story
# ./dailymail/stories/6f331c7895519ab732e64fdbcb0abe86d303f64a.story
# ./dailymail/stories/ddcfb6e4a69a75bb7b3489a26eb307e35a794ffa.story
# ./dailymail/stories/cbbb275f2820ee8683d6763180683d5612a4469a.story
# ./dailymail/stories/53d32d31c6f445f5a8072238def76cbea187bf6b.story
# ./dailymail/stories/4eeb001076de3c9b49deaa8bf785952337dba2b6.story
# ./dailymail/stories/ec899ca780f569a509ada534a93e847c46fd83d6.story
# ./dailymail/stories/49c9fa3b34ccd58a26c1e29495c6a1fdf64e053f.story
# ./dailymail/stories/b688f06b6176438d38f6f0de272442d7d705af2a.story
# ./dailymail/stories/592832e0ff5c3ccd773899af3101bffb20f25469.story
# ./dailymail/stories/59f2d6e69e5656b7933806ab19d96aab4e384396.story
# ./dailymail/stories/054d133653dbf6fa07651893f04b69ba308e4150.story
# ./dailymail/stories/7df09abd9d7a2b37bc5f33efdd96fe052716abc5.story
# ./dailymail/stories/f8dd2bd2852ba0d49c0b4b4a600f8d27c63282d1.story
# ./dailymail/stories/ffbf37b598cd4cb6be25732cf1609e03128e3d7a.story
# ./dailymail/stories/bcf7a94b2bf354cbd4e8a9a9989818cf9fd48c1a.story
# ./dailymail/stories/5942a6d999fb616a5097b4f6430408529a7c790c.story
# ./dailymail/stories/a3b6201aca77b5bdaa5df02d6acee2be66233237.story
# ./dailymail/stories/7d8389d498d79d1bcc367fa3c83e592386f2ce06.story
# ./dailymail/stories/b26f67ea97a275e5de9d48efafb85f7c23390419.story
# ./dailymail/stories/7cf05b7804301b6e7288e1e20fdd4bd8e996a968.story
# ./dailymail/stories/ff83029ffc440ebc5fc5dd3015825be6fb983b81.story
# ./dailymail/stories/8b07bd65175809d5457191cc3fa985b9e79ab978.story
# ./dailymail/stories/5e72a4afee3e580dd1164e651b1bb01ee679f627.story
# ./dailymail/stories/49aebeb876947f5c4f2a73f6fca20ba9eebfe271.story
# ./dailymail/stories/dfea410a35908a077eaa59c4a9738261781fa18c.story
# ./dailymail/stories/5f92bb8be1229d36f9e8b39b619f83cd77701559.story
# ./dailymail/stories/dccfab653e063f7bc99bfe089aaf69a732ad99ed.story
# ./dailymail/stories/8847383b72167c3f3dd2161b5b091b580c8f4da7.story
# ./dailymail/stories/cbb0f839506c43aa86dbaf99eaf1d439c6fc5737.story
# ./dailymail/stories/f2585a9406b45744f8c8bd6fec5c5803113d92d7.story
# ./dailymail/stories/11a163af84137675bba50d79ff4d2b081258f072.story
# ./dailymail/stories/49b00cde1ee02c39e298a96b394051241078ce94.story
# ./dailymail/stories/af55d7f2f9a0a583d9f62198bb94d994d7d9b95b.story
# ./dailymail/stories/33d1fe64e2e4a8a4cc7fe57206f7e49504b11709.story
# ./dailymail/stories/103a9ab47e8f90f42f92462986136bb0f377f0c7.story
# ./dailymail/stories/6fe5c3d6e9b54f0f1263595b9a0d789e21e56297.story
# ./dailymail/stories/fe4ab1f83fa064dffdc3ea480f70ed145421756e.story
# ./dailymail/stories/fa18d40e6b7e3c07176cd99a5378ee320985e2d2.story
# ./dailymail/stories/410bfca1ceb9a370c7bd2d4cdd299f03990f38b1.story
# ./dailymail/stories/e33105857efc5104b9ea6215187199a11e912726.story
# ./dailymail/stories/6b828bb69cdb5222024c421b4319a9584875cec1.story
# ./dailymail/stories/f40d3e3d68af0c13b0f907c47f4fac4254e86126.story
# ./dailymail/stories/39f02f3b87a6b1be687baf36d00bd72683eaa155.story
# ./dailymail/stories/a4d69c441fe3a2bcbf767e686ffbbb3b61f3b443.story
# ./dailymail/stories/15a00dc2b416e0e9000217b827df5d571932d4f1.story
# ./dailymail/stories/c4c9b8ca533c48a0bd97a8b9d5c1588a42ccc1e5.story
# ./dailymail/stories/7410c5d58bdce3612846cd07f0ebd0b5f5a787cc.story
# ./dailymail/stories/a052c3104c43f99b438d4dd0fb14fbef561432d4.story
# ./dailymail/stories/983cf8cfb8c2cc7de2033ba2b85fb4b87af794c8.story
# ./dailymail/stories/fef1c26ec17c2a32dcdba3c37719a4275b286496.story
# ./dailymail/stories/e1f967ec14cb4f560c45573fe438a16760956478.story
# ./dailymail/stories/412f5f9ab05322ab3f94fdf4025d29dc6af3f5c2.story
# ./dailymail/stories/a7252f57350b2ef20edf5a33ae4adacc0bc1d1f0.story
# ./dailymail/stories/2e6d5e2cddaaa8291d7bea81bf82ee992df1a771.story
# ./dailymail/stories/e165931f9f79b876b020c535ac7bf48a2b6b5f4f.story
# ./dailymail/stories/025455ecba4c0613d97f7d7303fa306699ddbcb4.story
# ./dailymail/stories/445985de4db5813847f14e214e0c43467098e206.story
# ./dailymail/stories/daa48f5d83361173f56595c47bf009147c3d12d1.story
# ./dailymail/stories/320c7e7badad9d2b8ea14132e0bba28c0f95f997.story
# ./dailymail/stories/b8dbcd5f6493c9f88801128dd0161c4a290f2c47.story
# ./dailymail/stories/28430943b851749f5adec57fed5627453542abd9.story
# ./dailymail/stories/402be4287af1839cf773d0eff56c637b1a4309a2.story
# ./dailymail/stories/653f8aac8bc1e1aa025ec3aa5d6edd533e6c2fe4.story
# ./dailymail/stories/cf5362fd2c7eb7ce3ae0651a6ad6fd06a9fe48dd.story
# ./dailymail/stories/fe635bfef7d0f1e975f772c9c31117422c7cd67a.story
# ./dailymail/stories/89fee504eaa27cc1c54a4e3034fd970b7508d39c.story
# ./dailymail/stories/3bfebb0fece05d9a0c1713107048eb4c79605ed8.story
# ./dailymail/stories/63650f9d134e429e802985d04f91f8019296935a.story
# ./dailymail/stories/3fde40c4955423a5cf32d62b93b36e7e0e616cc1.story
# ./dailymail/stories/094f27b7d1c22639a427c5eb7a0a56de5f802fb5.story
# ./dailymail/stories/37c4c2d7d529b761284384495ede504cfd1cd5db.story
# ./dailymail/stories/cefad1107c223ddfebdf96ce99cb3b0641bc9428.story
# ./dailymail/stories/95ce74f4affd98fa7f2b6de36c937b4d4f3ceb2f.story
# ./dailymail/stories/af7d35ca6b4d1467c6956c5729d6952e4da89f4b.story
# ./dailymail/stories/310fe6f4943d322320b053e3c61fb193aee6ba27.story
# ./dailymail/stories/38052e2a4541d00f6d16945bce46ddb21284943b.story
# ./dailymail/stories/fea9ce32e5219d6343be62b63f67adc450c39868.story
# ./dailymail/stories/7916d458a1b2ad7c1c89fa54a6e54f0a3c9e70e2.story
# ./dailymail/stories/eb47dc0668b13268d515d85867d63251285a2634.story
# ./dailymail/stories/355d0d81af8b895deacb576c153f5c2d5bcf3a06.story
# ./dailymail/stories/8403ba365fc1dc83426f2c9b4cc29b82f502a7ad.story
# ./dailymail/stories/f640c4990d2af49c18e1720a84420ab0fd01fc5c.story
# ./dailymail/stories/e865434d5fef489d5a6845e9998384aa0bbf648e.story
# ./dailymail/stories/5098fdb944301d1d2394f54a3d37c6bf96c17ea4.story
# ./dailymail/stories/dca50abe4ea90250a2b709816cde88c974a9e3fd.story
# ./dailymail/stories/7dbfe76b078ddcf738248766a03e37f50178acb7.story
# ./dailymail/stories/d3a2e087eb5ba79fbf9b78a6ae9491760b4cbb36.story
# ./dailymail/stories/75dff6de7fa16663f25b5b492dd1b3f2a895aafe.story
# ./dailymail/stories/9cffb331bf6e72b6ac3b867b7a8cbc8b28614819.story
# ./dailymail/stories/20478b52f4db007a5cfbd6b26f2bde38af55b6ad.story
# ./dailymail/stories/3572dee55c511d5fd647c1bec89dd866d4ea8644.story
# ./dailymail/stories/01b4613f86c44ceec7beb897c5167088c61deeac.story
# ./dailymail/stories/d32bc944f0c14f50a89dd32eeac8e3f80fddd420.story
# ./dailymail/stories/691cb23f2672964aa5af4606df7495b78be6c264.story
# ./dailymail/stories/6912add7664586646afec0e7cde09a88b605f5bd.story
# ./dailymail/stories/07c351e3489286a82551e53ade4c1e607ec31633.story
# ./dailymail/stories/088dc10acd872fca8c7a4fa1c9cbbe0d43e10319.story
# ./dailymail/stories/e7cf3fffdc93587e901c6499aaecffcf66f1a7ab.story
# ./dailymail/stories/b71a16e0e5d95e530f59e7aeaeb5c18904b87d9b.story
# ./dailymail/stories/ad667dee62fc2dfb077bb833f729950313bf0c47.story
# ./dailymail/stories/9d7cd85f70c1790c1c89db76485af7ec417ec96f.story
# ./dailymail/stories/cb40f01b4f8f5ce2b715ad606b5f3f2704fa9bac.story
# ./dailymail/stories/6ed4b69cba1ff7b4a5a3c37128266a8e0a596ddf.story
# ./dailymail/stories/3c8c0613344a28221620b6118fbe4aa09b4774c4.story
# ./dailymail/stories/6d0f1a5aeba1ab5e99159b022d89172f6341b066.story
# ./dailymail/stories/74e6580d118d607f0078d96d26a2d6967a7145f0.story
# ./dailymail/stories/cf5c92f09882dd51d4af27d31dfc19a685292b26.story
# ./dailymail/stories/63609f5542e8a07877f4b9efc6887f1f64d11c72.story
# ./dailymail/stories/f5e3ba89dda5bd18e9f49e7e11f96fa2dcfe7766.story
# ./dailymail/stories/0d317c1026b4d9b405cb70bc3d4157bfdfd5a11f.story
# ./dailymail/stories/c02c4dd532284e36ac6fb158ad58b359acbb9f42.story
# ./dailymail/stories/4a5eea58a042d6898178851851b1181b201c8d43.story
# ./dailymail/stories/d9f303f58c644eab9e600cf36516a62936efb0eb.story
# ./dailymail/stories/0eb888e7e1c4a7e1de903ecb74803cbbfb346689.story
# ./dailymail/stories/139ef1c29b64e6b7899ee19e091e4281ba1eb40d.story
# ./dailymail/stories/8f8a06aaf9f154fc7685a42c938a539d9d9f3000.story
# ./dailymail/stories/d0b23c7a0d80e1ff9bfbce6b73ffe2a3bc8f4ce0.story
# ./dailymail/stories/31e392657a7389e600ee11b54b5e86db2e716a19.story
# ./dailymail/stories/c6603bb12f48d959b902ee451e1976f1c7da3e08.story
# ./dailymail/stories/173e140b41a7be197c688beac5ed7f614e9640da.story
# ./dailymail/stories/3ffe0b53f10871c9212e94e99d6b1a0ef1e0f765.story
# ./dailymail/stories/a178270be15302556e4b7486878feb86c7740472.story
# ./dailymail/stories/4a6df221d64802f1e55c8e06d6f2d7a42a53593b.story
# ./dailymail/stories/b56e50294cadecb4a94acdf6fd0f63e5b930a868.story
# ./dailymail/stories/1c3c9cebc499fad2df637b654ac3c15db61a2761.story
# ./dailymail/stories/556772cc132b79d51a028b6b32206009d2e689b7.story
# ./dailymail/stories/8810349454fb9b083aafbea5313b7b264e88abf5.story
# ./dailymail/stories/47ebf6233d9af85783700a1d611930317258619e.story
# ./dailymail/stories/e2df23a9f991076e850fb410c337bbd5e20edd05.story
# ./dailymail/stories/45a9f7a9c4cffb0a068b65b08ad091ba69c53d5c.story
# ./dailymail/stories/bdcf697a5b23767ec974dd29acc92d32ff1d989a.story
# ./dailymail/stories/da7ebb260388df3561e7c7f5d82662352cfcbc83.story
# ./dailymail/stories/8a8c10afe58b3c2d71b7e60b20ddc5eaaffc6633.story
# ./dailymail/stories/1c4d35a128bce4d8d3d7cc7e08cad24a327070b6.story
# ./dailymail/stories/fbe5effa9f8821556e8154faa533cfaf08b6d9dc.story
# ./dailymail/stories/79117361d0bed0a7a3c78d0ea80463b9020523fe.story
# ./dailymail/stories/6502ddef68f4b8724bdf6bc7e04c5eb69c0c0df3.story
# ./dailymail/stories/81f258ce1bf966a049218911a69b7b818742f82a.story
# ./dailymail/stories/99c778f266292fa1300b83eeeb9c1e4aa0b4a4aa.story
# ./dailymail/stories/d4c14596198576e4fecde02b0ea9798853e799b9.story
# ./dailymail/stories/afba4641c27f4f0e6159d844e5e516dd88989feb.story
# ./dailymail/stories/0013aa16650fbcfbe6edb16ac614ad174cb5d1cf.story
# ./dailymail/stories/aebd9197842dbe6eacc3b4dfec482330ba16957a.story
# ./dailymail/stories/18514a002a1a244a68a560c63c4471af98f72a73.story
# ./dailymail/stories/3a15df7ddd82c6cd119f7a25824b41da27637b6a.story
# ./dailymail/stories/a5ca926be994dc0b3ff68df3b3c846306f2b47d3.story
# ./dailymail/stories/e35f57a1c55b0b914fe2ecdf73b47a10800bd371.story
# ./dailymail/stories/1c69b5c1b2fb520bb153ebf54687ec16dfa133ca.story
# ./dailymail/stories/9caf5bd46962494ceadafe08c3a5fb467809cc17.story
# ./dailymail/stories/70cad6d23e98138ee87f5efcc0891bff71d336a7.story
# ./dailymail/stories/05ee187dd0ee1d9c9d663500f303714f953d1ca5.story
# ./dailymail/stories/e00a9e90627c06dbb962e8445a30de4e6d3b4ea6.story
# ./dailymail/stories/eeeeef5ee0b5fc1bd5acabfb9208bdb75a53725e.story
# ./dailymail/stories/1988fa445927b9dc53ba4aabd3d075c3eecc6390.story
# ./dailymail/stories/152f09f208306c3f3f64906396969a7a57310704.story
# ./dailymail/stories/16eed6bfefe9d4813e41530ebe2e9401a604337b.story
# ./dailymail/stories/97bea23d3939621cb0504e61d2cbf1997938528f.story
# ./dailymail/stories/61a7858bb4209a440ab90297a3d3d38b16fb56a2.story
# ./dailymail/stories/e45eaf604cb1f2ccb3cf7d62592bc7fea4e799af.story
# ./dailymail/stories/7aefa3df2215604c3c0ecdecf51dd466bbb0fd03.story
# ./dailymail/stories/8a5b63a1e9c70ef06e432e29091603238831815f.story
# ./dailymail/stories/09bd6873911988de592b1696947d4bad280373db.story
# ./dailymail/stories/751d8494c6daa18b6ac493a07e713b95819dab6d.story
# ./dailymail/stories/2869e1ed9ce7940b91cc0d534880e7c6f278e9b3.story
# ./dailymail/stories/e62aad1577510747f644e321c81377f3c0c2885f.story
# ./dailymail/stories/dc680726929ab6d5c2c493cde84cd0e5fdc13673.story
# ./dailymail/stories/3d6c3f8e7ed92d4f34fbe3ef2c7913c7df708960.story
# ./dailymail/stories/8cbe6539cf37fcabbc8761e1a502bc6a3634afae.story
# ./dailymail/stories/30eeca51dcfef34ddf769051b69c869faa3e886e.story
# ./dailymail/stories/e3b38ff7835f48c6933e78e9b7203a40164b5687.story
# ./dailymail/stories/1d0199b2ab071564b0f519881cb177f86e7ca8b6.story
# ./dailymail/stories/0ac776a4dc09ca97c136f4314fed4defb48a361a.story
# ./dailymail/stories/fe89a6a2e28d173e5ad4c6d814c15b95aa969e3f.story
# ./dailymail/stories/ded2f535cd6ab95d11b5f4ea29bbf2b2d3c55c50.story
# ./dailymail/stories/30ec5f280eee772a73d181bfc8514defd8026434.story
# ./dailymail/stories/b4a1738c4a0acdf3d189264a0927005aa5b856d6.story

# %%
import torch
import torch.nn.functional as F
from datasets import load_dataset
from transformers import BartTokenizer, BartModel
from huggingface_hub import hf_hub_download

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load dataset and model
# Increase timeout for dataset download
try:
    # Note: Dataset loading is handled in a separate cell (06d288ad) with custom collate_fn
    # This cell now focuses on the model and training logic.
    pass # Dataset loading is not done here anymore
except Exception as e:
    print(f"Error loading dataset: {e}")
    print("Please check your internet connection or try again later.")
    # You might want to exit the cell execution here if the dataset is essential
    # raise e # Uncomment to re-raise the exception if needed

tokenizer = BartTokenizer.from_pretrained('facebook/bart-base')
bart_model = BartModel.from_pretrained('facebook/bart-base').to(device).eval()

# Embedding function
def get_embeddings(texts, tokenizer, model, device, max_length=512):
    """Get mean-pooled BART encoder embeddings for a batch of texts"""
    if len(texts) == 0:
        return torch.zeros(0, model.config.d_model, device=device)

    inputs = tokenizer(
        texts, return_tensors="pt", padding=True, truncation=True, max_length=max_length
    ).to(device)
    with torch.no_grad():
        outputs = model.encoder(**inputs)
        embeddings = outputs.last_hidden_state.mean(dim=1)  # mean pooling
    return embeddings

# Updated training function to correctly handle batch dictionary
def train_refinement(train_data_batch, net, optimizer, device, N_supervision=3):
    """
    Train recursive model for one batch using embedding-based supervision
    train_data_batch is expected to be a dictionary like {'article': [...], 'highlights': [...]}
    """
    if len(train_data_batch) == 0 or len(train_data_batch['article']) == 0:
        return 0.0  # skip empty batch

    # Prepare inputs - directly access the lists from the dictionary
    articles = train_data_batch['article']
    references = train_data_batch['highlights']

    # Get embeddings
    x_input = get_embeddings(articles, tokenizer, bart_model, device)  # document embeddings
    y_true_emb = get_embeddings(references, tokenizer, bart_model, device)  # target summary embeddings

    batch_size = x_input.size(0)

    # Ensure RecursionModel output dimension matches embedding size
    # If not, project fc_out to embedding size
    embedding_dim = y_true_emb.size(-1)
    if net.fc_out.out_features != embedding_dim:
        print(f"Adjusting fc_out output features to match embedding dimension: {embedding_dim}")
        net.fc_out = torch.nn.Linear(net.hidden_dim, embedding_dim).to(device)

    # Initialize latent vector z and output y
    # Ensure y is initialized with the correct size matching the embedding dimension
    y = torch.zeros(batch_size, embedding_dim, device=device)
    z = torch.zeros(batch_size, net.latent_dim, device=device)

    for _ in range(N_supervision):
        # Deep recursion step
        # Ensure the input dimension of the net matches the input_dim of deep_recursion
        # This was handled by ensuring x_input is correctly sized
        (y_detach, z_detach), y_hat, q_hat = deep_recursion(x_input, y, z, net)


        # Loss: MSE for embeddings + auxiliary confidence loss
        mse_loss = F.mse_loss(y_hat, y_true_emb)
        aux_loss = F.binary_cross_entropy(q_hat, torch.ones_like(q_hat))
        loss = mse_loss + 0.1 * aux_loss

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(net.parameters(), 1.0)
        optimizer.step()

        # Update y and z for next deep supervision step
        y = y_detach
        z = z_detach

        # Early stopping if confident
        if q_hat.mean() > 0.95:
            break

    return loss.item()

# %%
input_dim = bart_model.config.d_model
hidden_dim = 128
latent_dim = 64
num_classes = 768  # will be adjusted dynamically in train_refinement

net = RecursionModel(input_dim, hidden_dim, latent_dim, num_classes).to(device)
optimizer = torch.optim.Adam(net.parameters(), lr=1e-3)

# %%
from torch.utils.data import default_collate

# Define a custom collate function to handle the dictionary output of the dataset
def custom_collate_fn(batch):
    """
    Collate function for the CNNDailyMailDataset that handles batches of dictionaries.
    """
    # Assuming each item in the batch is a dictionary with the same keys,
    # e.g., {'article': '...', 'highlights': '...'}
    # We want to return a dictionary where each key maps to a list of values from the batch
    collated_batch = {}
    for key in batch[0].keys():
        collated_batch[key] = [item[key] for item in batch]
    return collated_batch

print("Custom collate_fn defined.")
# Out:
# Custom collate_fn defined.

# %%
import os
from torch.utils.data import Dataset, DataLoader

class CNNDailyMailDataset(Dataset):
    def __init__(self, folder_path, max_samples=None):
        self.articles = []
        self.summaries = []
        cnn_path = os.path.join(folder_path, "cnn")
        dm_path = os.path.join(folder_path, "dailymail")

        # Read CNN stories
        cnn_story_path = os.path.join(cnn_path, "stories") # Navigate into the 'stories' directory
        for fname in os.listdir(cnn_story_path):
            fpath = os.path.join(cnn_story_path, fname)
            if os.path.isfile(fpath): # Check if it's a file
                with open(fpath, 'r', encoding='utf-8') as f:
                    self.articles.append(f.read())

        # Read DailyMail stories
        dm_story_path = os.path.join(dm_path, "stories") # Navigate into the 'stories' directory
        for fname in os.listdir(dm_story_path):
            fpath = os.path.join(dm_story_path, fname)
            if os.path.isfile(fpath): # Check if it's a file
                with open(fpath, 'r', encoding='utf-8') as f:
                    self.summaries.append(f.read())


        # Use subset for quick testing
        if max_samples:
            self.articles = self.articles[:max_samples]
            self.summaries = self.summaries[:max_samples]

        assert len(self.articles) == len(self.summaries), "Mismatch in number of articles and summaries"
        print(f"Loaded {len(self.articles)} samples from CNN/DailyMail dataset.")


    def __len__(self):
        return len(self.articles)

    def __getitem__(self, idx):
        return {
            "article": self.articles[idx],
            "highlights": self.summaries[idx]
        }

# Create dataset and dataloader
dataset = CNNDailyMailDataset("/content/cnn_dailymail", max_samples=64)  # small subset for testing
dataloader = DataLoader(dataset, batch_size=8, shuffle=True, collate_fn=custom_collate_fn) # Use the custom collate_fn
# Out:
# Loaded 64 samples from CNN/DailyMail dataset.

# %%
# Run training for 2 epochs for testing

if 'net' not in locals():
    print("Model 'net' not found. Please initialize the model.")
elif 'optimizer' not in locals():
    print("Optimizer 'optimizer' not found. Please initialize the optimizer.")
elif 'dataloader' not in locals():
    print("DataLoader 'dataloader' not found. Please load the dataset and create the dataloader.")
else:
    num_epochs = 2 # Set number of epochs for testing
    N_supervision = 3 # Number of deep supervision steps (adjust as needed)

    print(f"Starting training for {num_epochs} epochs...")

    for epoch in range(num_epochs):
        net.train() # Set model to training mode
        total_loss = 0

        for batch_idx, train_data_batch in enumerate(dataloader):
            # train_data_batch is a dictionary of lists due to custom_collate_fn
            loss = train_refinement(train_data_batch, net, optimizer, device, N_supervision)
            total_loss += loss

            if (batch_idx + 1) % 10 == 0: # Print loss every 10 batches
                print(f"Epoch [{epoch+1}/{num_epochs}], Batch [{batch_idx+1}/{len(dataloader)}], Loss: {loss:.4f}")


        avg_loss = total_loss / len(dataloader)
        print(f"Epoch [{epoch+1}/{num_epochs}] finished, Average Loss: {avg_loss:.4f}")

    print("Training finished.")
# Out:
# Starting training for 2 epochs...
# Epoch [1/2] finished, Average Loss: 0.0577
# Epoch [2/2] finished, Average Loss: 0.0296
# Training finished.

# %%
# Example inference on first batch
batch = next(iter(dataloader))
articles = batch['article'] # Correctly access the list of articles from the batch dictionary
x_input = get_embeddings(articles, tokenizer, bart_model, device)

batch_size = x_input.size(0)
y = torch.zeros(batch_size, net.fc_out.out_features, device=device)
z = torch.zeros(batch_size, net.latent_dim, device=device)

# Set model to evaluation mode
net.eval()
with torch.no_grad(): # No gradient calculation during inference
    (_, _), y_hat, q_hat = deep_recursion(x_input, y, z, net)

print("Predicted embedding shape:", y_hat.shape)
print("Prediction confidence:", q_hat)

# Optional: If you have target summaries for this batch, you could also calculate loss or similarity
references = batch['highlights']
print(references)
y_true_emb = get_embeddings(references, tokenizer, bart_model, device)
mse_loss = F.mse_loss(y_hat, y_true_emb)
print("MSE Loss with target embeddings:", mse_loss.item())
# Out:
# Predicted embedding shape: torch.Size([8, 768])
# Prediction confidence: tensor([0.8385, 0.8808, 0.8645, 0.9256, 0.8386, 0.8121, 0.8769, 0.9273],
#        device='cuda:0')
# ["This is the moment a pit bull owner whose dogs fatally mauled a 63-year-old grandmother was sentenced to at least fifteen years in prison on murder charges.\n\nAlex Jackson, 31, cast his eyes to the floor in despair as he was handed a the sentence - which could extend to life in prison - after being convicted of second-degree murder for his dogs' attack on Pamela Devitt.\xa0\xa0\n\nMrs Devitt was taking a morning stroll in  Littlerock, California, when four of Jackson's dogs leaped over a fence and attacked her in the street, biting her 200 times.\n\nDespair: Alex Jackson, right, reacts to the sentence while his defense attorney, Al Kim, covers his face\n\nJailed: Dog owner Alex Jackson, 31, (left) has been jailed for at least fifteen years after being convicted of the murder of Pamela Devitt, 63 (right)\n\nShe was alone, didn't have a phone and no one was nearby.\xa0\n\nBy the time help arrived, she had been bitten from head to toe and an arm was severed.\n\nShe died from blood loss.\n\nSentencing Jackson to 15 years in jail, Deputy District Attorney Ryan Williams said:\xa0'His actions in this case show that he has a nearly psychopathic disregard for the lives and well-being of others.'\xa0\n\nJackson was initially arrested when deputies searching for the dogs discovered a marijuana-growing operation in his house.\xa0\n\nEmotional: Ben Devitt, the husband of Mrs Devitt, spoke out today during the sentencing in a California court\n\nSentence: Judge Lisa Chung speaks during the sentencing of Alex Jackson\n\nHe was later charged with murder when Devitt's DNA was found on his dogs' bloody fur.\n\nProsecutors in Los Angeles County Superior Court sought a term of 24 years to life in prison for the murder and convictions on weapon and drug charges.\xa0\n\nThe dogs guarded Jackson's pot-growing operation and he knew the animals were dangerous, Williams said.\n\nBrutal: The court heard Jackson had done nothing to contain his dogs (one pictured) despite complaints\n\nAnd records showed neighbors had complained that his dogs were vicious or dangerous and that the he didn't do enough to control the animals.\xa0\n\nA murder conviction for a killing by dogs is rare.\n\nThe mauling of Diane Whipple in the hallway outside her San Francisco apartment in 2001 led to her neighbor's second-degree murder conviction.\n\nA Michigan couple is facing trial on second-degree murder charges for the mauling death of a jogger in July by two cane corsos, an Italian mastiff-type breed, near their home about 45 miles outside Detroit.\n\nTo be convicted, it must be proven the accused did something so reckless they had to know it was dangerous enough to kill someone — even without intending harm.\xa0\xa0\n\nDistraught: Pamela's grieving husband Ben Devitt holds a picture of his wife of 43 years\n\nNine witnesses, including several horse riders and a postal worker, testified about seven frightening encounters. One equestrian had offered to provide free fencing and help Jackson put it up to keep the dogs on his property, but Jackson did not accept the help.\n\nAccording to Jackson's defense lawyer, Al Kim, the 'nail in the coffin' was that the number of other incidents made it hard to argue that he wasn't aware of the danger the dogs posed.\n\nAt trial, Kim conceded Jackson was a drug dealer, but also said he was a dog lover who took in strays that reproduced. While he should have kept closer watch of them, he never intended to hurt someone.\n\n'He's not the evil dude he's being made out to be,' Kim said. 'He feels horrible about this. He's contrite.'\n\n@highlight\n\nAlex Jackson, 31, was found guilty last month of murder\n\n@highlight\n\nHis four pit bulls leaped on Pamela Devitt, 63, bit her 200 times\n\n@highlight\n\nShe lost an arm, died of blood loss during morning stroll in California\n\n@highlight\n\nJackson has been jailed for 15 years to life in Lancaster, near LA", "By\nLizzie Parry\n\nAfter eight years missing, living on the streets and battling th ...
# MSE Loss with target embeddings: 0.01360262930393219
